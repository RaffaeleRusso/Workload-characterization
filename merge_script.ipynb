# %%
import pandas as pd
import os

# %%
df1 = pd.read_csv("./client/client.csv")
df2 = pd.read_csv("./server/server.csv")

df = pd.merge(df1, df2, on='label')

# %%
df.drop(columns=["label"],inplace=True)
df.head()
# Out:
#   Throughput  errors      elapsed      Latency  VmPeak  VmRSS  VmSize  VmHWM  \
# 0   31,11111     0.0    26.571429     2.571429  209060  10652  209060    NaN
# 1    6,14979     0.0  1414.928571  1363.892857  209060  10652  209060    NaN
# 2    5,50206     0.0    39.250000     1.500000  209060  10652  209060    NaN
# 3    6,75676     0.0    44.200000     1.800000  209060  10652  209060    NaN
# 4   32,25806     0.0    31.000000     1.000000  209060  10652  209060    NaN
#
#    VmPTE  Threads  ...  Inactive  Dirty  Writeback  AnonPages  Mapped    Slab  \
# 0    148        1  ...   1974052    112          0    2172380  495488  238056
# 1    148        1  ...   1957424    116          0    2153252  495416  237960
# 2    148        1  ...   1953796    116          0    2153040  491360  238144
# 3    148        1  ...   1950400    112          0    2153892  486976  238628
# 4    148        1  ...   1951976     96         16    2160696  487008  239844
#
#    PageTables  Committed_AS  NumOfAllocFH  proc_fd
# 0       35480       8738984         11072    11072
# 1       35468       8737012         11104    11104
# 2       35656       8749236         11104    11104
# 3       36484       8780488         11104    11072
# 4       37712       8853752         11104    11104
#
# [5 rows x 24 columns]

# %%
if not os.path.isfile('dataset.csv'):
   df.to_csv('dataset.csv',index=False)
else: 
   df.to_csv('dataset.csv', index = False,mode='a', header=False)
