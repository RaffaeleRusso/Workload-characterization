# %%
import threading
import time
import os 
import pandas as pd
from datetime import datetime
import subprocess

# %%
apache_pid = os.popen("ps aux | grep -i apache | head -1 | awk ' { print $2 } ' ").read().replace("\n",'')
print(f"Apache pid : {apache_pid}")
# Out:
# Apache pid : 1491

# %%
headers = ["VmPeak","VmRSS","VmSize","VmHWM","VmPTE","Threads","MemFree","Buffers","Cached","Active","Inactive","Dirty","Writeback","AnonPages","Mapped","Slab","PageTables","Committed_AS","NumOfAllocFH","proc_fd","label"]

# %%
VmPeak= subprocess.check_output("grep VmPeak /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmRSS = subprocess.check_output("grep VmRSS /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmSize = subprocess.check_output("grep VmSize /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmHWM = subprocess.check_output("grep VmHWM/ proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmPTE = subprocess.check_output("grep VmPTE /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
Threads = subprocess.check_output("grep Threads /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
MemFree = subprocess.check_output("grep MemFree /proc/meminfo | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Buffers = subprocess.check_output("grep Buffers /proc/meminfo | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Cached = subprocess.check_output("grep Cached /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Active = subprocess.check_output("grep Active /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Inactive = subprocess.check_output("grep Inactive /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Dirty = subprocess.check_output("grep Dirty /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Writeback = subprocess.check_output("grep Writeback /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
AnonPages = subprocess.check_output("grep AnonPages /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Mapped = subprocess.check_output("grep Mapped /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Slab = subprocess.check_output("grep Slab /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
PageTables =  subprocess.check_output("grep PageTables /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Committed_AS =  subprocess.check_output("grep Committed_AS /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
NumOfAllocFH = subprocess.check_output("head -1 /proc/sys/fs/file-nr | awk ' {print $1}' ",cwd = "/",shell=True).decode('utf-8')
proc_fd = subprocess.check_output("cat /proc/sys/fs/file-nr | awk ' { print $1 } '",cwd = "/",shell=True).decode('utf-8')

# %%
commands = [
    "grep VmPeak /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmRSS /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmSize /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmHWM/ proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmPTE /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep Threads /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep MemFree /proc/meminfo | awk ' { print $2}'",
    "grep Buffers /proc/meminfo | awk ' { print $2}'",
    "grep Cached /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Active /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Inactive /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Dirty /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Writeback /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep AnonPages /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Mapped /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Slab /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep PageTables /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Committed_AS /proc/meminfo |  head -1 | awk ' { print $2}'",
    "head -1 /proc/sys/fs/file-nr | awk ' {print $1}' ",
    "cat /proc/sys/fs/file-nr | awk ' { print $1 } '"
]

# %%
outputs = [[] for _ in range(len(commands)+1)] #the last one is for the timestamp

# %%
def fun(i):
    val = subprocess.check_output(commands[i],cwd = "/",shell=True).decode('utf-8').replace("\n",'')
    outputs[i].append(val)

# %%
n_it = 620
for it in range(n_it):
    threads = [threading.Thread(target = fun,args = (i,))for i in range(len(commands))]
    outputs[len(commands)].append(str(datetime.now())[-15:-7])
    for thread in threads:
        thread.start()
        print(f'Iterazione: {it} Thread_name = {thread.name}')
    thread.join()
    time.sleep(1)
# Out:
# Iterazione: 0 Thread_name = Thread-12404 (fun)
# Iterazione: 0 Thread_name = Thread-12405 (fun)
# Iterazione: 0 Thread_name = Thread-12406 (fun)
# Iterazione: 0 Thread_name = Thread-12407 (fun)
# Iterazione: 0 Thread_name = Thread-12408 (fun)
# Iterazione: 0 Thread_name = Thread-12409 (fun)
# Iterazione: 0 Thread_name = Thread-12410 (fun)
# Iterazione: 0 Thread_name = Thread-12411 (fun)
# Iterazione: 0 Thread_name = Thread-12412 (fun)
# Iterazione: 0 Thread_name = Thread-12413 (fun)
# Iterazione: 0 Thread_name = Thread-12414 (fun)
# Iterazione: 0 Thread_name = Thread-12415 (fun)
# Iterazione: 0 Thread_name = Thread-12416 (fun)
# Iterazione: 0 Thread_name = Thread-12417 (fun)
# Iterazione: 0 Thread_name = Thread-12418 (fun)
# Iterazione: 0 Thread_name = Thread-12419 (fun)
# Iterazione: 0 Thread_name = Thread-12420 (fun)
# Iterazione: 0 Thread_name = Thread-12421 (fun)
# Iterazione: 0 Thread_name = Thread-12422 (fun)
# Iterazione: 0 Thread_name = Thread-12423 (fun)
# Iterazione: 1 Thread_name = Thread-12424 (fun)
# Iterazione: 1 Thread_name = Thread-12425 (fun)
# Iterazione: 1 Thread_name = Thread-12426 (fun)
# Iterazione: 1 Thread_name = Thread-12427 (fun)
# Iterazione: 1 Thread_name = Thread-12428 (fun)
# Iterazione: 1 Thread_name = Thread-12429 (fun)
# Iterazione: 1 Thread_name = Thread-12430 (fun)
# Iterazione: 1 Thread_name = Thread-12431 (fun)
# Iterazione: 1 Thread_name = Thread-12432 (fun)
# Iterazione: 1 Thread_name = Thread-12433 (fun)
# Iterazione: 1 Thread_name = Thread-12434 (fun)
# Iterazione: 1 Thread_name = Thread-12435 (fun)
# Iterazione: 1 Thread_name = Thread-12436 (fun)
# Iterazione: 1 Thread_name = Thread-12437 (fun)
# Iterazione: 1 Thread_name = Thread-12438 (fun)
# Iterazione: 1 Thread_name = Thread-12439 (fun)
# Iterazione: 1 Thread_name = Thread-12440 (fun)
# Iterazione: 1 Thread_name = Thread-12441 (fun)
# Iterazione: 1 Thread_name = Thread-12442 (fun)
# Iterazione: 1 Thread_name = Thread-12443 (fun)
# Iterazione: 2 Thread_name = Thread-12444 (fun)
# Iterazione: 2 Thread_name = Thread-12445 (fun)
# Iterazione: 2 Thread_name = Thread-12446 (fun)
# Iterazione: 2 Thread_name = Thread-12447 (fun)
# Iterazione: 2 Thread_name = Thread-12448 (fun)
# Iterazione: 2 Thread_name = Thread-12449 (fun)
# Iterazione: 2 Thread_name = Thread-12450 (fun)
# Iterazione: 2 Thread_name = Thread-12451 (fun)
# Iterazione: 2 Thread_name = Thread-12452 (fun)
# Iterazione: 2 Thread_name = Thread-12453 (fun)
# Iterazione: 2 Thread_name = Thread-12454 (fun)
# Iterazione: 2 Thread_name = Thread-12455 (fun)
# Iterazione: 2 Thread_name = Thread-12456 (fun)
# Iterazione: 2 Thread_name = Thread-12457 (fun)
# Iterazione: 2 Thread_name = Thread-12458 (fun)
# Iterazione: 2 Thread_name = Thread-12459 (fun)
# Iterazione: 2 Thread_name = Thread-12460 (fun)
# Iterazione: 2 Thread_name = Thread-12461 (fun)
# Iterazione: 2 Thread_name = Thread-12462 (fun)
# Iterazione: 2 Thread_name = Thread-12463 (fun)
# Iterazione: 3 Thread_name = Thread-12464 (fun)
# Iterazione: 3 Thread_name = Thread-12465 (fun)
# Iterazione: 3 Thread_name = Thread-12466 (fun)
# Iterazione: 3 Thread_name = Thread-12467 (fun)
# Iterazione: 3 Thread_name = Thread-12468 (fun)
# Iterazione: 3 Thread_name = Thread-12469 (fun)
# Iterazione: 3 Thread_name = Thread-12470 (fun)
# Iterazione: 3 Thread_name = Thread-12471 (fun)
# Iterazione: 3 Thread_name = Thread-12472 (fun)
# Iterazione: 3 Thread_name = Thread-12473 (fun)
# Iterazione: 3 Thread_name = Thread-12474 (fun)
# Iterazione: 3 Thread_name = Thread-12475 (fun)
# Iterazione: 3 Thread_name = Thread-12476 (fun)
# Iterazione: 3 Thread_name = Thread-12477 (fun)
# Iterazione: 3 Thread_name = Thread-12478 (fun)
# Iterazione: 3 Thread_name = Thread-12479 (fun)
# Iterazione: 3 Thread_name = Thread-12480 (fun)
# Iterazione: 3 Thread_name = Thread-12481 (fun)
# Iterazione: 3 Thread_name = Thread-12482 (fun)
# Iterazione: 3 Thread_name = Thread-12483 (fun)
# Iterazione: 4 Thread_name = Thread-12484 (fun)
# Iterazione: 4 Thread_name = Thread-12485 (fun)
# Iterazione: 4 Thread_name = Thread-12486 (fun)
# Iterazione: 4 Thread_name = Thread-12487 (fun)
# Iterazione: 4 Thread_name = Thread-12488 (fun)
# Iterazione: 4 Thread_name = Thread-12489 (fun)
# Iterazione: 4 Thread_name = Thread-12490 (fun)
# Iterazione: 4 Thread_name = Thread-12491 (fun)
# Iterazione: 4 Thread_name = Thread-12492 (fun)
# Iterazione: 4 Thread_name = Thread-12493 (fun)
# Iterazione: 4 Thread_name = Thread-12494 (fun)
# Iterazione: 4 Thread_name = Thread-12495 (fun)
# Iterazione: 4 Thread_name = Thread-12496 (fun)
# Iterazione: 4 Thread_name = Thread-12497 (fun)
# Iterazione: 4 Thread_name = Thread-12498 (fun)
# Iterazione: 4 Thread_name = Thread-12499 (fun)
# Iterazione: 4 Thread_name = Thread-12500 (fun)
# Iterazione: 4 Thread_name = Thread-12501 (fun)
# Iterazione: 4 Thread_name = Thread-12502 (fun)
# Iterazione: 4 Thread_name = Thread-12503 (fun)
# Iterazione: 5 Thread_name = Thread-12504 (fun)
# Iterazione: 5 Thread_name = Thread-12505 (fun)
# Iterazione: 5 Thread_name = Thread-12506 (fun)
# Iterazione: 5 Thread_name = Thread-12507 (fun)
# Iterazione: 5 Thread_name = Thread-12508 (fun)
# Iterazione: 5 Thread_name = Thread-12509 (fun)
# Iterazione: 5 Thread_name = Thread-12510 (fun)
# Iterazione: 5 Thread_name = Thread-12511 (fun)
# Iterazione: 5 Thread_name = Thread-12512 (fun)
# Iterazione: 5 Thread_name = Thread-12513 (fun)
# Iterazione: 5 Thread_name = Thread-12514 (fun)
# Iterazione: 5 Thread_name = Thread-12515 (fun)
# Iterazione: 5 Thread_name = Thread-12516 (fun)
# Iterazione: 5 Thread_name = Thread-12517 (fun)
# Iterazione: 5 Thread_name = Thread-12518 (fun)
# Iterazione: 5 Thread_name = Thread-12519 (fun)
# Iterazione: 5 Thread_name = Thread-12520 (fun)
# Iterazione: 5 Thread_name = Thread-12521 (fun)
# Iterazione: 5 Thread_name = Thread-12522 (fun)
# Iterazione: 5 Thread_name = Thread-12523 (fun)
# Iterazione: 6 Thread_name = Thread-12524 (fun)
# Iterazione: 6 Thread_name = Thread-12525 (fun)
# Iterazione: 6 Thread_name = Thread-12526 (fun)
# Iterazione: 6 Thread_name = Thread-12527 (fun)
# Iterazione: 6 Thread_name = Thread-12528 (fun)
# Iterazione: 6 Thread_name = Thread-12529 (fun)
# Iterazione: 6 Thread_name = Thread-12530 (fun)
# Iterazione: 6 Thread_name = Thread-12531 (fun)
# Iterazione: 6 Thread_name = Thread-12532 (fun)
# Iterazione: 6 Thread_name = Thread-12533 (fun)
# Iterazione: 6 Thread_name = Thread-12534 (fun)
# Iterazione: 6 Thread_name = Thread-12535 (fun)
# Iterazione: 6 Thread_name = Thread-12536 (fun)
# Iterazione: 6 Thread_name = Thread-12537 (fun)
# Iterazione: 6 Thread_name = Thread-12538 (fun)
# Iterazione: 6 Thread_name = Thread-12539 (fun)
# Iterazione: 6 Thread_name = Thread-12540 (fun)
# Iterazione: 6 Thread_name = Thread-12541 (fun)
# Iterazione: 6 Thread_name = Thread-12542 (fun)
# Iterazione: 6 Thread_name = Thread-12543 (fun)
# Iterazione: 7 Thread_name = Thread-12544 (fun)
# Iterazione: 7 Thread_name = Thread-12545 (fun)
# Iterazione: 7 Thread_name = Thread-12546 (fun)
# Iterazione: 7 Thread_name = Thread-12547 (fun)
# Iterazione: 7 Thread_name = Thread-12548 (fun)
# Iterazione: 7 Thread_name = Thread-12549 (fun)
# Iterazione: 7 Thread_name = Thread-12550 (fun)
# Iterazione: 7 Thread_name = Thread-12551 (fun)
# Iterazione: 7 Thread_name = Thread-12552 (fun)
# Iterazione: 7 Thread_name = Thread-12553 (fun)
# Iterazione: 7 Thread_name = Thread-12554 (fun)
# Iterazione: 7 Thread_name = Thread-12555 (fun)
# Iterazione: 7 Thread_name = Thread-12556 (fun)
# Iterazione: 7 Thread_name = Thread-12557 (fun)
# Iterazione: 7 Thread_name = Thread-12558 (fun)
# Iterazione: 7 Thread_name = Thread-12559 (fun)
# Iterazione: 7 Thread_name = Thread-12560 (fun)
# Iterazione: 7 Thread_name = Thread-12561 (fun)
# Iterazione: 7 Thread_name = Thread-12562 (fun)
# Iterazione: 7 Thread_name = Thread-12563 (fun)
# Iterazione: 8 Thread_name = Thread-12564 (fun)
# Iterazione: 8 Thread_name = Thread-12565 (fun)
# Iterazione: 8 Thread_name = Thread-12566 (fun)
# Iterazione: 8 Thread_name = Thread-12567 (fun)
# Iterazione: 8 Thread_name = Thread-12568 (fun)
# Iterazione: 8 Thread_name = Thread-12569 (fun)
# Iterazione: 8 Thread_name = Thread-12570 (fun)
# Iterazione: 8 Thread_name = Thread-12571 (fun)
# Iterazione: 8 Thread_name = Thread-12572 (fun)
# Iterazione: 8 Thread_name = Thread-12573 (fun)
# Iterazione: 8 Thread_name = Thread-12574 (fun)
# Iterazione: 8 Thread_name = Thread-12575 (fun)
# Iterazione: 8 Thread_name = Thread-12576 (fun)
# Iterazione: 8 Thread_name = Thread-12577 (fun)
# Iterazione: 8 Thread_name = Thread-12578 (fun)
# Iterazione: 8 Thread_name = Thread-12579 (fun)
# Iterazione: 8 Thread_name = Thread-12580 (fun)
# Iterazione: 8 Thread_name = Thread-12581 (fun)
# Iterazione: 8 Thread_name = Thread-12582 (fun)
# Iterazione: 8 Thread_name = Thread-12583 (fun)
# Iterazione: 9 Thread_name = Thread-12584 (fun)
# Iterazione: 9 Thread_name = Thread-12585 (fun)
# Iterazione: 9 Thread_name = Thread-12586 (fun)
# Iterazione: 9 Thread_name = Thread-12587 (fun)
# Iterazione: 9 Thread_name = Thread-12588 (fun)
# Iterazione: 9 Thread_name = Thread-12589 (fun)
# Iterazione: 9 Thread_name = Thread-12590 (fun)
# Iterazione: 9 Thread_name = Thread-12591 (fun)
# Iterazione: 9 Thread_name = Thread-12592 (fun)
# Iterazione: 9 Thread_name = Thread-12593 (fun)
# Iterazione: 9 Thread_name = Thread-12594 (fun)
# Iterazione: 9 Thread_name = Thread-12595 (fun)
# Iterazione: 9 Thread_name = Thread-12596 (fun)
# Iterazione: 9 Thread_name = Thread-12597 (fun)
# Iterazione: 9 Thread_name = Thread-12598 (fun)
# Iterazione: 9 Thread_name = Thread-12599 (fun)
# Iterazione: 9 Thread_name = Thread-12600 (fun)
# Iterazione: 9 Thread_name = Thread-12601 (fun)
# Iterazione: 9 Thread_name = Thread-12602 (fun)
# Iterazione: 9 Thread_name = Thread-12603 (fun)
# Iterazione: 10 Thread_name = Thread-12604 (fun)
# Iterazione: 10 Thread_name = Thread-12605 (fun)
# Iterazione: 10 Thread_name = Thread-12606 (fun)
# Iterazione: 10 Thread_name = Thread-12607 (fun)
# Iterazione: 10 Thread_name = Thread-12608 (fun)
# Iterazione: 10 Thread_name = Thread-12609 (fun)
# Iterazione: 10 Thread_name = Thread-12610 (fun)
# Iterazione: 10 Thread_name = Thread-12611 (fun)
# Iterazione: 10 Thread_name = Thread-12612 (fun)
# Iterazione: 10 Thread_name = Thread-12613 (fun)
# Iterazione: 10 Thread_name = Thread-12614 (fun)
# Iterazione: 10 Thread_name = Thread-12615 (fun)
# Iterazione: 10 Thread_name = Thread-12616 (fun)
# Iterazione: 10 Thread_name = Thread-12617 (fun)
# Iterazione: 10 Thread_name = Thread-12618 (fun)
# Iterazione: 10 Thread_name = Thread-12619 (fun)
# Iterazione: 10 Thread_name = Thread-12620 (fun)
# Iterazione: 10 Thread_name = Thread-12621 (fun)
# Iterazione: 10 Thread_name = Thread-12622 (fun)
# Iterazione: 10 Thread_name = Thread-12623 (fun)
# Iterazione: 11 Thread_name = Thread-12624 (fun)
# Iterazione: 11 Thread_name = Thread-12625 (fun)
# Iterazione: 11 Thread_name = Thread-12626 (fun)
# Iterazione: 11 Thread_name = Thread-12627 (fun)
# Iterazione: 11 Thread_name = Thread-12628 (fun)
# Iterazione: 11 Thread_name = Thread-12629 (fun)
# Iterazione: 11 Thread_name = Thread-12630 (fun)
# Iterazione: 11 Thread_name = Thread-12631 (fun)
# Iterazione: 11 Thread_name = Thread-12632 (fun)
# Iterazione: 11 Thread_name = Thread-12633 (fun)
# Iterazione: 11 Thread_name = Thread-12634 (fun)
# Iterazione: 11 Thread_name = Thread-12635 (fun)
# Iterazione: 11 Thread_name = Thread-12636 (fun)
# Iterazione: 11 Thread_name = Thread-12637 (fun)
# Iterazione: 11 Thread_name = Thread-12638 (fun)
# Iterazione: 11 Thread_name = Thread-12639 (fun)
# Iterazione: 11 Thread_name = Thread-12640 (fun)
# Iterazione: 11 Thread_name = Thread-12641 (fun)
# Iterazione: 11 Thread_name = Thread-12642 (fun)
# Iterazione: 11 Thread_name = Thread-12643 (fun)
# Iterazione: 12 Thread_name = Thread-12644 (fun)
# Iterazione: 12 Thread_name = Thread-12645 (fun)
# Iterazione: 12 Thread_name = Thread-12646 (fun)
# Iterazione: 12 Thread_name = Thread-12647 (fun)
# Iterazione: 12 Thread_name = Thread-12648 (fun)
# Iterazione: 12 Thread_name = Thread-12649 (fun)
# Iterazione: 12 Thread_name = Thread-12650 (fun)
# Iterazione: 12 Thread_name = Thread-12651 (fun)
# Iterazione: 12 Thread_name = Thread-12652 (fun)
# Iterazione: 12 Thread_name = Thread-12653 (fun)
# Iterazione: 12 Thread_name = Thread-12654 (fun)
# Iterazione: 12 Thread_name = Thread-12655 (fun)
# Iterazione: 12 Thread_name = Thread-12656 (fun)
# Iterazione: 12 Thread_name = Thread-12657 (fun)
# Iterazione: 12 Thread_name = Thread-12658 (fun)
# Iterazione: 12 Thread_name = Thread-12659 (fun)
# Iterazione: 12 Thread_name = Thread-12660 (fun)
# Iterazione: 12 Thread_name = Thread-12661 (fun)
# Iterazione: 12 Thread_name = Thread-12662 (fun)
# Iterazione: 12 Thread_name = Thread-12663 (fun)
# Iterazione: 13 Thread_name = Thread-12664 (fun)
# Iterazione: 13 Thread_name = Thread-12665 (fun)
# Iterazione: 13 Thread_name = Thread-12666 (fun)
# Iterazione: 13 Thread_name = Thread-12667 (fun)
# Iterazione: 13 Thread_name = Thread-12668 (fun)
# Iterazione: 13 Thread_name = Thread-12669 (fun)
# Iterazione: 13 Thread_name = Thread-12670 (fun)
# Iterazione: 13 Thread_name = Thread-12671 (fun)
# Iterazione: 13 Thread_name = Thread-12672 (fun)
# Iterazione: 13 Thread_name = Thread-12673 (fun)
# Iterazione: 13 Thread_name = Thread-12674 (fun)
# Iterazione: 13 Thread_name = Thread-12675 (fun)
# Iterazione: 13 Thread_name = Thread-12676 (fun)
# Iterazione: 13 Thread_name = Thread-12677 (fun)
# Iterazione: 13 Thread_name = Thread-12678 (fun)
# Iterazione: 13 Thread_name = Thread-12679 (fun)
# Iterazione: 13 Thread_name = Thread-12680 (fun)
# Iterazione: 13 Thread_name = Thread-12681 (fun)
# Iterazione: 13 Thread_name = Thread-12682 (fun)
# Iterazione: 13 Thread_name = Thread-12683 (fun)
# Iterazione: 14 Thread_name = Thread-12684 (fun)
# Iterazione: 14 Thread_name = Thread-12685 (fun)
# Iterazione: 14 Thread_name = Thread-12686 (fun)
# Iterazione: 14 Thread_name = Thread-12687 (fun)
# Iterazione: 14 Thread_name = Thread-12688 (fun)
# Iterazione: 14 Thread_name = Thread-12689 (fun)
# Iterazione: 14 Thread_name = Thread-12690 (fun)
# Iterazione: 14 Thread_name = Thread-12691 (fun)
# Iterazione: 14 Thread_name = Thread-12692 (fun)
# Iterazione: 14 Thread_name = Thread-12693 (fun)
# Iterazione: 14 Thread_name = Thread-12694 (fun)
# Iterazione: 14 Thread_name = Thread-12695 (fun)
# Iterazione: 14 Thread_name = Thread-12696 (fun)
# Iterazione: 14 Thread_name = Thread-12697 (fun)
# Iterazione: 14 Thread_name = Thread-12698 (fun)
# Iterazione: 14 Thread_name = Thread-12699 (fun)
# Iterazione: 14 Thread_name = Thread-12700 (fun)
# Iterazione: 14 Thread_name = Thread-12701 (fun)
# Iterazione: 14 Thread_name = Thread-12702 (fun)
# Iterazione: 14 Thread_name = Thread-12703 (fun)
# Iterazione: 15 Thread_name = Thread-12704 (fun)
# Iterazione: 15 Thread_name = Thread-12705 (fun)
# Iterazione: 15 Thread_name = Thread-12706 (fun)
# Iterazione: 15 Thread_name = Thread-12707 (fun)
# Iterazione: 15 Thread_name = Thread-12708 (fun)
# Iterazione: 15 Thread_name = Thread-12709 (fun)
# Iterazione: 15 Thread_name = Thread-12710 (fun)
# Iterazione: 15 Thread_name = Thread-12711 (fun)
# Iterazione: 15 Thread_name = Thread-12712 (fun)
# Iterazione: 15 Thread_name = Thread-12713 (fun)
# Iterazione: 15 Thread_name = Thread-12714 (fun)
# Iterazione: 15 Thread_name = Thread-12715 (fun)
# Iterazione: 15 Thread_name = Thread-12716 (fun)
# Iterazione: 15 Thread_name = Thread-12717 (fun)
# Iterazione: 15 Thread_name = Thread-12718 (fun)
# Iterazione: 15 Thread_name = Thread-12719 (fun)
# Iterazione: 15 Thread_name = Thread-12720 (fun)
# Iterazione: 15 Thread_name = Thread-12721 (fun)
# Iterazione: 15 Thread_name = Thread-12722 (fun)
# Iterazione: 15 Thread_name = Thread-12723 (fun)
# Iterazione: 16 Thread_name = Thread-12724 (fun)
# Iterazione: 16 Thread_name = Thread-12725 (fun)
# Iterazione: 16 Thread_name = Thread-12726 (fun)
# Iterazione: 16 Thread_name = Thread-12727 (fun)
# Iterazione: 16 Thread_name = Thread-12728 (fun)
# Iterazione: 16 Thread_name = Thread-12729 (fun)
# Iterazione: 16 Thread_name = Thread-12730 (fun)
# Iterazione: 16 Thread_name = Thread-12731 (fun)
# Iterazione: 16 Thread_name = Thread-12732 (fun)
# Iterazione: 16 Thread_name = Thread-12733 (fun)
# Iterazione: 16 Thread_name = Thread-12734 (fun)
# Iterazione: 16 Thread_name = Thread-12735 (fun)
# Iterazione: 16 Thread_name = Thread-12736 (fun)
# Iterazione: 16 Thread_name = Thread-12737 (fun)
# Iterazione: 16 Thread_name = Thread-12738 (fun)
# Iterazione: 16 Thread_name = Thread-12739 (fun)
# Iterazione: 16 Thread_name = Thread-12740 (fun)
# Iterazione: 16 Thread_name = Thread-12741 (fun)
# Iterazione: 16 Thread_name = Thread-12742 (fun)
# Iterazione: 16 Thread_name = Thread-12743 (fun)
# Iterazione: 17 Thread_name = Thread-12744 (fun)
# Iterazione: 17 Thread_name = Thread-12745 (fun)
# Iterazione: 17 Thread_name = Thread-12746 (fun)
# Iterazione: 17 Thread_name = Thread-12747 (fun)
# Iterazione: 17 Thread_name = Thread-12748 (fun)
# Iterazione: 17 Thread_name = Thread-12749 (fun)
# Iterazione: 17 Thread_name = Thread-12750 (fun)
# Iterazione: 17 Thread_name = Thread-12751 (fun)
# Iterazione: 17 Thread_name = Thread-12752 (fun)
# Iterazione: 17 Thread_name = Thread-12753 (fun)
# Iterazione: 17 Thread_name = Thread-12754 (fun)
# Iterazione: 17 Thread_name = Thread-12755 (fun)
# Iterazione: 17 Thread_name = Thread-12756 (fun)
# Iterazione: 17 Thread_name = Thread-12757 (fun)
# Iterazione: 17 Thread_name = Thread-12758 (fun)
# Iterazione: 17 Thread_name = Thread-12759 (fun)
# Iterazione: 17 Thread_name = Thread-12760 (fun)
# Iterazione: 17 Thread_name = Thread-12761 (fun)
# Iterazione: 17 Thread_name = Thread-12762 (fun)
# Iterazione: 17 Thread_name = Thread-12763 (fun)
# Iterazione: 18 Thread_name = Thread-12764 (fun)
# Iterazione: 18 Thread_name = Thread-12765 (fun)
# Iterazione: 18 Thread_name = Thread-12766 (fun)
# Iterazione: 18 Thread_name = Thread-12767 (fun)
# Iterazione: 18 Thread_name = Thread-12768 (fun)
# Iterazione: 18 Thread_name = Thread-12769 (fun)
# Iterazione: 18 Thread_name = Thread-12770 (fun)
# Iterazione: 18 Thread_name = Thread-12771 (fun)
# Iterazione: 18 Thread_name = Thread-12772 (fun)
# Iterazione: 18 Thread_name = Thread-12773 (fun)
# Iterazione: 18 Thread_name = Thread-12774 (fun)
# Iterazione: 18 Thread_name = Thread-12775 (fun)
# Iterazione: 18 Thread_name = Thread-12776 (fun)
# Iterazione: 18 Thread_name = Thread-12777 (fun)
# Iterazione: 18 Thread_name = Thread-12778 (fun)
# Iterazione: 18 Thread_name = Thread-12779 (fun)
# Iterazione: 18 Thread_name = Thread-12780 (fun)
# Iterazione: 18 Thread_name = Thread-12781 (fun)
# Iterazione: 18 Thread_name = Thread-12782 (fun)
# Iterazione: 18 Thread_name = Thread-12783 (fun)
# Iterazione: 19 Thread_name = Thread-12784 (fun)
# Iterazione: 19 Thread_name = Thread-12785 (fun)
# Iterazione: 19 Thread_name = Thread-12786 (fun)
# Iterazione: 19 Thread_name = Thread-12787 (fun)
# Iterazione: 19 Thread_name = Thread-12788 (fun)
# Iterazione: 19 Thread_name = Thread-12789 (fun)
# Iterazione: 19 Thread_name = Thread-12790 (fun)
# Iterazione: 19 Thread_name = Thread-12791 (fun)
# Iterazione: 19 Thread_name = Thread-12792 (fun)
# Iterazione: 19 Thread_name = Thread-12793 (fun)
# Iterazione: 19 Thread_name = Thread-12794 (fun)
# Iterazione: 19 Thread_name = Thread-12795 (fun)
# Iterazione: 19 Thread_name = Thread-12796 (fun)
# Iterazione: 19 Thread_name = Thread-12797 (fun)
# Iterazione: 19 Thread_name = Thread-12798 (fun)
# Iterazione: 19 Thread_name = Thread-12799 (fun)
# Iterazione: 19 Thread_name = Thread-12800 (fun)
# Iterazione: 19 Thread_name = Thread-12801 (fun)
# Iterazione: 19 Thread_name = Thread-12802 (fun)
# Iterazione: 19 Thread_name = Thread-12803 (fun)
# Iterazione: 20 Thread_name = Thread-12804 (fun)
# Iterazione: 20 Thread_name = Thread-12805 (fun)
# Iterazione: 20 Thread_name = Thread-12806 (fun)
# Iterazione: 20 Thread_name = Thread-12807 (fun)
# Iterazione: 20 Thread_name = Thread-12808 (fun)
# Iterazione: 20 Thread_name = Thread-12809 (fun)
# Iterazione: 20 Thread_name = Thread-12810 (fun)
# Iterazione: 20 Thread_name = Thread-12811 (fun)
# Iterazione: 20 Thread_name = Thread-12812 (fun)
# Iterazione: 20 Thread_name = Thread-12813 (fun)
# Iterazione: 20 Thread_name = Thread-12814 (fun)
# Iterazione: 20 Thread_name = Thread-12815 (fun)
# Iterazione: 20 Thread_name = Thread-12816 (fun)
# Iterazione: 20 Thread_name = Thread-12817 (fun)
# Iterazione: 20 Thread_name = Thread-12818 (fun)
# Iterazione: 20 Thread_name = Thread-12819 (fun)
# Iterazione: 20 Thread_name = Thread-12820 (fun)
# Iterazione: 20 Thread_name = Thread-12821 (fun)
# Iterazione: 20 Thread_name = Thread-12822 (fun)
# Iterazione: 20 Thread_name = Thread-12823 (fun)
# Iterazione: 21 Thread_name = Thread-12824 (fun)
# Iterazione: 21 Thread_name = Thread-12825 (fun)
# Iterazione: 21 Thread_name = Thread-12826 (fun)
# Iterazione: 21 Thread_name = Thread-12827 (fun)
# Iterazione: 21 Thread_name = Thread-12828 (fun)
# Iterazione: 21 Thread_name = Thread-12829 (fun)
# Iterazione: 21 Thread_name = Thread-12830 (fun)
# Iterazione: 21 Thread_name = Thread-12831 (fun)
# Iterazione: 21 Thread_name = Thread-12832 (fun)
# Iterazione: 21 Thread_name = Thread-12833 (fun)
# Iterazione: 21 Thread_name = Thread-12834 (fun)
# Iterazione: 21 Thread_name = Thread-12835 (fun)
# Iterazione: 21 Thread_name = Thread-12836 (fun)
# Iterazione: 21 Thread_name = Thread-12837 (fun)
# Iterazione: 21 Thread_name = Thread-12838 (fun)
# Iterazione: 21 Thread_name = Thread-12839 (fun)
# Iterazione: 21 Thread_name = Thread-12840 (fun)
# Iterazione: 21 Thread_name = Thread-12841 (fun)
# Iterazione: 21 Thread_name = Thread-12842 (fun)
# Iterazione: 21 Thread_name = Thread-12843 (fun)
# Iterazione: 22 Thread_name = Thread-12844 (fun)
# Iterazione: 22 Thread_name = Thread-12845 (fun)
# Iterazione: 22 Thread_name = Thread-12846 (fun)
# Iterazione: 22 Thread_name = Thread-12847 (fun)
# Iterazione: 22 Thread_name = Thread-12848 (fun)
# Iterazione: 22 Thread_name = Thread-12849 (fun)
# Iterazione: 22 Thread_name = Thread-12850 (fun)
# Iterazione: 22 Thread_name = Thread-12851 (fun)
# Iterazione: 22 Thread_name = Thread-12852 (fun)
# Iterazione: 22 Thread_name = Thread-12853 (fun)
# Iterazione: 22 Thread_name = Thread-12854 (fun)
# Iterazione: 22 Thread_name = Thread-12855 (fun)
# Iterazione: 22 Thread_name = Thread-12856 (fun)
# Iterazione: 22 Thread_name = Thread-12857 (fun)
# Iterazione: 22 Thread_name = Thread-12858 (fun)
# Iterazione: 22 Thread_name = Thread-12859 (fun)
# Iterazione: 22 Thread_name = Thread-12860 (fun)
# Iterazione: 22 Thread_name = Thread-12861 (fun)
# Iterazione: 22 Thread_name = Thread-12862 (fun)
# Iterazione: 22 Thread_name = Thread-12863 (fun)
# Iterazione: 23 Thread_name = Thread-12864 (fun)
# Iterazione: 23 Thread_name = Thread-12865 (fun)
# Iterazione: 23 Thread_name = Thread-12866 (fun)
# Iterazione: 23 Thread_name = Thread-12867 (fun)
# Iterazione: 23 Thread_name = Thread-12868 (fun)
# Iterazione: 23 Thread_name = Thread-12869 (fun)
# Iterazione: 23 Thread_name = Thread-12870 (fun)
# Iterazione: 23 Thread_name = Thread-12871 (fun)
# Iterazione: 23 Thread_name = Thread-12872 (fun)
# Iterazione: 23 Thread_name = Thread-12873 (fun)
# Iterazione: 23 Thread_name = Thread-12874 (fun)
# Iterazione: 23 Thread_name = Thread-12875 (fun)
# Iterazione: 23 Thread_name = Thread-12876 (fun)
# Iterazione: 23 Thread_name = Thread-12877 (fun)
# Iterazione: 23 Thread_name = Thread-12878 (fun)
# Iterazione: 23 Thread_name = Thread-12879 (fun)
# Iterazione: 23 Thread_name = Thread-12880 (fun)
# Iterazione: 23 Thread_name = Thread-12881 (fun)
# Iterazione: 23 Thread_name = Thread-12882 (fun)
# Iterazione: 23 Thread_name = Thread-12883 (fun)
# Iterazione: 24 Thread_name = Thread-12884 (fun)
# Iterazione: 24 Thread_name = Thread-12885 (fun)
# Iterazione: 24 Thread_name = Thread-12886 (fun)
# Iterazione: 24 Thread_name = Thread-12887 (fun)
# Iterazione: 24 Thread_name = Thread-12888 (fun)
# Iterazione: 24 Thread_name = Thread-12889 (fun)
# Iterazione: 24 Thread_name = Thread-12890 (fun)
# Iterazione: 24 Thread_name = Thread-12891 (fun)
# Iterazione: 24 Thread_name = Thread-12892 (fun)
# Iterazione: 24 Thread_name = Thread-12893 (fun)
# Iterazione: 24 Thread_name = Thread-12894 (fun)
# Iterazione: 24 Thread_name = Thread-12895 (fun)
# Iterazione: 24 Thread_name = Thread-12896 (fun)
# Iterazione: 24 Thread_name = Thread-12897 (fun)
# Iterazione: 24 Thread_name = Thread-12898 (fun)
# Iterazione: 24 Thread_name = Thread-12899 (fun)
# Iterazione: 24 Thread_name = Thread-12900 (fun)
# Iterazione: 24 Thread_name = Thread-12901 (fun)
# Iterazione: 24 Thread_name = Thread-12902 (fun)
# Iterazione: 24 Thread_name = Thread-12903 (fun)
# Iterazione: 25 Thread_name = Thread-12904 (fun)
# Iterazione: 25 Thread_name = Thread-12905 (fun)
# Iterazione: 25 Thread_name = Thread-12906 (fun)
# Iterazione: 25 Thread_name = Thread-12907 (fun)
# Iterazione: 25 Thread_name = Thread-12908 (fun)
# Iterazione: 25 Thread_name = Thread-12909 (fun)
# Iterazione: 25 Thread_name = Thread-12910 (fun)
# Iterazione: 25 Thread_name = Thread-12911 (fun)
# Iterazione: 25 Thread_name = Thread-12912 (fun)
# Iterazione: 25 Thread_name = Thread-12913 (fun)
# Iterazione: 25 Thread_name = Thread-12914 (fun)
# Iterazione: 25 Thread_name = Thread-12915 (fun)
# Iterazione: 25 Thread_name = Thread-12916 (fun)
# Iterazione: 25 Thread_name = Thread-12917 (fun)
# Iterazione: 25 Thread_name = Thread-12918 (fun)
# Iterazione: 25 Thread_name = Thread-12919 (fun)
# Iterazione: 25 Thread_name = Thread-12920 (fun)
# Iterazione: 25 Thread_name = Thread-12921 (fun)
# Iterazione: 25 Thread_name = Thread-12922 (fun)
# Iterazione: 25 Thread_name = Thread-12923 (fun)
# Iterazione: 26 Thread_name = Thread-12924 (fun)
# Iterazione: 26 Thread_name = Thread-12925 (fun)
# Iterazione: 26 Thread_name = Thread-12926 (fun)
# Iterazione: 26 Thread_name = Thread-12927 (fun)
# Iterazione: 26 Thread_name = Thread-12928 (fun)
# Iterazione: 26 Thread_name = Thread-12929 (fun)
# Iterazione: 26 Thread_name = Thread-12930 (fun)
# Iterazione: 26 Thread_name = Thread-12931 (fun)
# Iterazione: 26 Thread_name = Thread-12932 (fun)
# Iterazione: 26 Thread_name = Thread-12933 (fun)
# Iterazione: 26 Thread_name = Thread-12934 (fun)
# Iterazione: 26 Thread_name = Thread-12935 (fun)
# Iterazione: 26 Thread_name = Thread-12936 (fun)
# Iterazione: 26 Thread_name = Thread-12937 (fun)
# Iterazione: 26 Thread_name = Thread-12938 (fun)
# Iterazione: 26 Thread_name = Thread-12939 (fun)
# Iterazione: 26 Thread_name = Thread-12940 (fun)
# Iterazione: 26 Thread_name = Thread-12941 (fun)
# Iterazione: 26 Thread_name = Thread-12942 (fun)
# Iterazione: 26 Thread_name = Thread-12943 (fun)
# Iterazione: 27 Thread_name = Thread-12944 (fun)
# Iterazione: 27 Thread_name = Thread-12945 (fun)
# Iterazione: 27 Thread_name = Thread-12946 (fun)
# Iterazione: 27 Thread_name = Thread-12947 (fun)
# Iterazione: 27 Thread_name = Thread-12948 (fun)
# Iterazione: 27 Thread_name = Thread-12949 (fun)
# Iterazione: 27 Thread_name = Thread-12950 (fun)
# Iterazione: 27 Thread_name = Thread-12951 (fun)
# Iterazione: 27 Thread_name = Thread-12952 (fun)
# Iterazione: 27 Thread_name = Thread-12953 (fun)
# Iterazione: 27 Thread_name = Thread-12954 (fun)
# Iterazione: 27 Thread_name = Thread-12955 (fun)
# Iterazione: 27 Thread_name = Thread-12956 (fun)
# Iterazione: 27 Thread_name = Thread-12957 (fun)
# Iterazione: 27 Thread_name = Thread-12958 (fun)
# Iterazione: 27 Thread_name = Thread-12959 (fun)
# Iterazione: 27 Thread_name = Thread-12960 (fun)
# Iterazione: 27 Thread_name = Thread-12961 (fun)
# Iterazione: 27 Thread_name = Thread-12962 (fun)
# Iterazione: 27 Thread_name = Thread-12963 (fun)
# Iterazione: 28 Thread_name = Thread-12964 (fun)
# Iterazione: 28 Thread_name = Thread-12965 (fun)
# Iterazione: 28 Thread_name = Thread-12966 (fun)
# Iterazione: 28 Thread_name = Thread-12967 (fun)
# Iterazione: 28 Thread_name = Thread-12968 (fun)
# Iterazione: 28 Thread_name = Thread-12969 (fun)
# Iterazione: 28 Thread_name = Thread-12970 (fun)
# Iterazione: 28 Thread_name = Thread-12971 (fun)
# Iterazione: 28 Thread_name = Thread-12972 (fun)
# Iterazione: 28 Thread_name = Thread-12973 (fun)
# Iterazione: 28 Thread_name = Thread-12974 (fun)
# Iterazione: 28 Thread_name = Thread-12975 (fun)
# Iterazione: 28 Thread_name = Thread-12976 (fun)
# Iterazione: 28 Thread_name = Thread-12977 (fun)
# Iterazione: 28 Thread_name = Thread-12978 (fun)
# Iterazione: 28 Thread_name = Thread-12979 (fun)
# Iterazione: 28 Thread_name = Thread-12980 (fun)
# Iterazione: 28 Thread_name = Thread-12981 (fun)
# Iterazione: 28 Thread_name = Thread-12982 (fun)
# Iterazione: 28 Thread_name = Thread-12983 (fun)
# Iterazione: 29 Thread_name = Thread-12984 (fun)
# Iterazione: 29 Thread_name = Thread-12985 (fun)
# Iterazione: 29 Thread_name = Thread-12986 (fun)
# Iterazione: 29 Thread_name = Thread-12987 (fun)
# Iterazione: 29 Thread_name = Thread-12988 (fun)
# Iterazione: 29 Thread_name = Thread-12989 (fun)
# Iterazione: 29 Thread_name = Thread-12990 (fun)
# Iterazione: 29 Thread_name = Thread-12991 (fun)
# Iterazione: 29 Thread_name = Thread-12992 (fun)
# Iterazione: 29 Thread_name = Thread-12993 (fun)
# Iterazione: 29 Thread_name = Thread-12994 (fun)
# Iterazione: 29 Thread_name = Thread-12995 (fun)
# Iterazione: 29 Thread_name = Thread-12996 (fun)
# Iterazione: 29 Thread_name = Thread-12997 (fun)
# Iterazione: 29 Thread_name = Thread-12998 (fun)
# Iterazione: 29 Thread_name = Thread-12999 (fun)
# Iterazione: 29 Thread_name = Thread-13000 (fun)
# Iterazione: 29 Thread_name = Thread-13001 (fun)
# Iterazione: 29 Thread_name = Thread-13002 (fun)
# Iterazione: 29 Thread_name = Thread-13003 (fun)
# Iterazione: 30 Thread_name = Thread-13004 (fun)
# Iterazione: 30 Thread_name = Thread-13005 (fun)
# Iterazione: 30 Thread_name = Thread-13006 (fun)
# Iterazione: 30 Thread_name = Thread-13007 (fun)
# Iterazione: 30 Thread_name = Thread-13008 (fun)
# Iterazione: 30 Thread_name = Thread-13009 (fun)
# Iterazione: 30 Thread_name = Thread-13010 (fun)
# Iterazione: 30 Thread_name = Thread-13011 (fun)
# Iterazione: 30 Thread_name = Thread-13012 (fun)
# Iterazione: 30 Thread_name = Thread-13013 (fun)
# Iterazione: 30 Thread_name = Thread-13014 (fun)
# Iterazione: 30 Thread_name = Thread-13015 (fun)
# Iterazione: 30 Thread_name = Thread-13016 (fun)
# Iterazione: 30 Thread_name = Thread-13017 (fun)
# Iterazione: 30 Thread_name = Thread-13018 (fun)
# Iterazione: 30 Thread_name = Thread-13019 (fun)
# Iterazione: 30 Thread_name = Thread-13020 (fun)
# Iterazione: 30 Thread_name = Thread-13021 (fun)
# Iterazione: 30 Thread_name = Thread-13022 (fun)
# Iterazione: 30 Thread_name = Thread-13023 (fun)
# Iterazione: 31 Thread_name = Thread-13024 (fun)
# Iterazione: 31 Thread_name = Thread-13025 (fun)
# Iterazione: 31 Thread_name = Thread-13026 (fun)
# Iterazione: 31 Thread_name = Thread-13027 (fun)
# Iterazione: 31 Thread_name = Thread-13028 (fun)
# Iterazione: 31 Thread_name = Thread-13029 (fun)
# Iterazione: 31 Thread_name = Thread-13030 (fun)
# Iterazione: 31 Thread_name = Thread-13031 (fun)
# Iterazione: 31 Thread_name = Thread-13032 (fun)
# Iterazione: 31 Thread_name = Thread-13033 (fun)
# Iterazione: 31 Thread_name = Thread-13034 (fun)
# Iterazione: 31 Thread_name = Thread-13035 (fun)
# Iterazione: 31 Thread_name = Thread-13036 (fun)
# Iterazione: 31 Thread_name = Thread-13037 (fun)
# Iterazione: 31 Thread_name = Thread-13038 (fun)
# Iterazione: 31 Thread_name = Thread-13039 (fun)
# Iterazione: 31 Thread_name = Thread-13040 (fun)
# Iterazione: 31 Thread_name = Thread-13041 (fun)
# Iterazione: 31 Thread_name = Thread-13042 (fun)
# Iterazione: 31 Thread_name = Thread-13043 (fun)
# Iterazione: 32 Thread_name = Thread-13044 (fun)
# Iterazione: 32 Thread_name = Thread-13045 (fun)
# Iterazione: 32 Thread_name = Thread-13046 (fun)
# Iterazione: 32 Thread_name = Thread-13047 (fun)
# Iterazione: 32 Thread_name = Thread-13048 (fun)
# Iterazione: 32 Thread_name = Thread-13049 (fun)
# Iterazione: 32 Thread_name = Thread-13050 (fun)
# Iterazione: 32 Thread_name = Thread-13051 (fun)
# Iterazione: 32 Thread_name = Thread-13052 (fun)
# Iterazione: 32 Thread_name = Thread-13053 (fun)
# Iterazione: 32 Thread_name = Thread-13054 (fun)
# Iterazione: 32 Thread_name = Thread-13055 (fun)
# Iterazione: 32 Thread_name = Thread-13056 (fun)
# Iterazione: 32 Thread_name = Thread-13057 (fun)
# Iterazione: 32 Thread_name = Thread-13058 (fun)
# Iterazione: 32 Thread_name = Thread-13059 (fun)
# Iterazione: 32 Thread_name = Thread-13060 (fun)
# Iterazione: 32 Thread_name = Thread-13061 (fun)
# Iterazione: 32 Thread_name = Thread-13062 (fun)
# Iterazione: 32 Thread_name = Thread-13063 (fun)
# Iterazione: 33 Thread_name = Thread-13064 (fun)
# Iterazione: 33 Thread_name = Thread-13065 (fun)
# Iterazione: 33 Thread_name = Thread-13066 (fun)
# Iterazione: 33 Thread_name = Thread-13067 (fun)
# Iterazione: 33 Thread_name = Thread-13068 (fun)
# Iterazione: 33 Thread_name = Thread-13069 (fun)
# Iterazione: 33 Thread_name = Thread-13070 (fun)
# Iterazione: 33 Thread_name = Thread-13071 (fun)
# Iterazione: 33 Thread_name = Thread-13072 (fun)
# Iterazione: 33 Thread_name = Thread-13073 (fun)
# Iterazione: 33 Thread_name = Thread-13074 (fun)
# Iterazione: 33 Thread_name = Thread-13075 (fun)
# Iterazione: 33 Thread_name = Thread-13076 (fun)
# Iterazione: 33 Thread_name = Thread-13077 (fun)
# Iterazione: 33 Thread_name = Thread-13078 (fun)
# Iterazione: 33 Thread_name = Thread-13079 (fun)
# Iterazione: 33 Thread_name = Thread-13080 (fun)
# Iterazione: 33 Thread_name = Thread-13081 (fun)
# Iterazione: 33 Thread_name = Thread-13082 (fun)
# Iterazione: 33 Thread_name = Thread-13083 (fun)
# Iterazione: 34 Thread_name = Thread-13084 (fun)
# Iterazione: 34 Thread_name = Thread-13085 (fun)
# Iterazione: 34 Thread_name = Thread-13086 (fun)
# Iterazione: 34 Thread_name = Thread-13087 (fun)
# Iterazione: 34 Thread_name = Thread-13088 (fun)
# Iterazione: 34 Thread_name = Thread-13089 (fun)
# Iterazione: 34 Thread_name = Thread-13090 (fun)
# Iterazione: 34 Thread_name = Thread-13091 (fun)
# Iterazione: 34 Thread_name = Thread-13092 (fun)
# Iterazione: 34 Thread_name = Thread-13093 (fun)
# Iterazione: 34 Thread_name = Thread-13094 (fun)
# Iterazione: 34 Thread_name = Thread-13095 (fun)
# Iterazione: 34 Thread_name = Thread-13096 (fun)
# Iterazione: 34 Thread_name = Thread-13097 (fun)
# Iterazione: 34 Thread_name = Thread-13098 (fun)
# Iterazione: 34 Thread_name = Thread-13099 (fun)
# Iterazione: 34 Thread_name = Thread-13100 (fun)
# Iterazione: 34 Thread_name = Thread-13101 (fun)
# Iterazione: 34 Thread_name = Thread-13102 (fun)
# Iterazione: 34 Thread_name = Thread-13103 (fun)
# Iterazione: 35 Thread_name = Thread-13104 (fun)
# Iterazione: 35 Thread_name = Thread-13105 (fun)
# Iterazione: 35 Thread_name = Thread-13106 (fun)
# Iterazione: 35 Thread_name = Thread-13107 (fun)
# Iterazione: 35 Thread_name = Thread-13108 (fun)
# Iterazione: 35 Thread_name = Thread-13109 (fun)
# Iterazione: 35 Thread_name = Thread-13110 (fun)
# Iterazione: 35 Thread_name = Thread-13111 (fun)
# Iterazione: 35 Thread_name = Thread-13112 (fun)
# Iterazione: 35 Thread_name = Thread-13113 (fun)
# Iterazione: 35 Thread_name = Thread-13114 (fun)
# Iterazione: 35 Thread_name = Thread-13115 (fun)
# Iterazione: 35 Thread_name = Thread-13116 (fun)
# Iterazione: 35 Thread_name = Thread-13117 (fun)
# Iterazione: 35 Thread_name = Thread-13118 (fun)
# Iterazione: 35 Thread_name = Thread-13119 (fun)
# Iterazione: 35 Thread_name = Thread-13120 (fun)
# Iterazione: 35 Thread_name = Thread-13121 (fun)
# Iterazione: 35 Thread_name = Thread-13122 (fun)
# Iterazione: 35 Thread_name = Thread-13123 (fun)
# Iterazione: 36 Thread_name = Thread-13124 (fun)
# Iterazione: 36 Thread_name = Thread-13125 (fun)
# Iterazione: 36 Thread_name = Thread-13126 (fun)
# Iterazione: 36 Thread_name = Thread-13127 (fun)
# Iterazione: 36 Thread_name = Thread-13128 (fun)
# Iterazione: 36 Thread_name = Thread-13129 (fun)
# Iterazione: 36 Thread_name = Thread-13130 (fun)
# Iterazione: 36 Thread_name = Thread-13131 (fun)
# Iterazione: 36 Thread_name = Thread-13132 (fun)
# Iterazione: 36 Thread_name = Thread-13133 (fun)
# Iterazione: 36 Thread_name = Thread-13134 (fun)
# Iterazione: 36 Thread_name = Thread-13135 (fun)
# Iterazione: 36 Thread_name = Thread-13136 (fun)
# Iterazione: 36 Thread_name = Thread-13137 (fun)
# Iterazione: 36 Thread_name = Thread-13138 (fun)
# Iterazione: 36 Thread_name = Thread-13139 (fun)
# Iterazione: 36 Thread_name = Thread-13140 (fun)
# Iterazione: 36 Thread_name = Thread-13141 (fun)
# Iterazione: 36 Thread_name = Thread-13142 (fun)
# Iterazione: 36 Thread_name = Thread-13143 (fun)
# Iterazione: 37 Thread_name = Thread-13144 (fun)
# Iterazione: 37 Thread_name = Thread-13145 (fun)
# Iterazione: 37 Thread_name = Thread-13146 (fun)
# Iterazione: 37 Thread_name = Thread-13147 (fun)
# Iterazione: 37 Thread_name = Thread-13148 (fun)
# Iterazione: 37 Thread_name = Thread-13149 (fun)
# Iterazione: 37 Thread_name = Thread-13150 (fun)
# Iterazione: 37 Thread_name = Thread-13151 (fun)
# Iterazione: 37 Thread_name = Thread-13152 (fun)
# Iterazione: 37 Thread_name = Thread-13153 (fun)
# Iterazione: 37 Thread_name = Thread-13154 (fun)
# Iterazione: 37 Thread_name = Thread-13155 (fun)
# Iterazione: 37 Thread_name = Thread-13156 (fun)
# Iterazione: 37 Thread_name = Thread-13157 (fun)
# Iterazione: 37 Thread_name = Thread-13158 (fun)
# Iterazione: 37 Thread_name = Thread-13159 (fun)
# Iterazione: 37 Thread_name = Thread-13160 (fun)
# Iterazione: 37 Thread_name = Thread-13161 (fun)
# Iterazione: 37 Thread_name = Thread-13162 (fun)
# Iterazione: 37 Thread_name = Thread-13163 (fun)
# Iterazione: 38 Thread_name = Thread-13164 (fun)
# Iterazione: 38 Thread_name = Thread-13165 (fun)
# Iterazione: 38 Thread_name = Thread-13166 (fun)
# Iterazione: 38 Thread_name = Thread-13167 (fun)
# Iterazione: 38 Thread_name = Thread-13168 (fun)
# Iterazione: 38 Thread_name = Thread-13169 (fun)
# Iterazione: 38 Thread_name = Thread-13170 (fun)
# Iterazione: 38 Thread_name = Thread-13171 (fun)
# Iterazione: 38 Thread_name = Thread-13172 (fun)
# Iterazione: 38 Thread_name = Thread-13173 (fun)
# Iterazione: 38 Thread_name = Thread-13174 (fun)
# Iterazione: 38 Thread_name = Thread-13175 (fun)
# Iterazione: 38 Thread_name = Thread-13176 (fun)
# Iterazione: 38 Thread_name = Thread-13177 (fun)
# Iterazione: 38 Thread_name = Thread-13178 (fun)
# Iterazione: 38 Thread_name = Thread-13179 (fun)
# Iterazione: 38 Thread_name = Thread-13180 (fun)
# Iterazione: 38 Thread_name = Thread-13181 (fun)
# Iterazione: 38 Thread_name = Thread-13182 (fun)
# Iterazione: 38 Thread_name = Thread-13183 (fun)
# Iterazione: 39 Thread_name = Thread-13184 (fun)
# Iterazione: 39 Thread_name = Thread-13185 (fun)
# Iterazione: 39 Thread_name = Thread-13186 (fun)
# Iterazione: 39 Thread_name = Thread-13187 (fun)
# Iterazione: 39 Thread_name = Thread-13188 (fun)
# Iterazione: 39 Thread_name = Thread-13189 (fun)
# Iterazione: 39 Thread_name = Thread-13190 (fun)
# Iterazione: 39 Thread_name = Thread-13191 (fun)
# Iterazione: 39 Thread_name = Thread-13192 (fun)
# Iterazione: 39 Thread_name = Thread-13193 (fun)
# Iterazione: 39 Thread_name = Thread-13194 (fun)
# Iterazione: 39 Thread_name = Thread-13195 (fun)
# Iterazione: 39 Thread_name = Thread-13196 (fun)
# Iterazione: 39 Thread_name = Thread-13197 (fun)
# Iterazione: 39 Thread_name = Thread-13198 (fun)
# Iterazione: 39 Thread_name = Thread-13199 (fun)
# Iterazione: 39 Thread_name = Thread-13200 (fun)
# Iterazione: 39 Thread_name = Thread-13201 (fun)
# Iterazione: 39 Thread_name = Thread-13202 (fun)
# Iterazione: 39 Thread_name = Thread-13203 (fun)
# Iterazione: 40 Thread_name = Thread-13204 (fun)
# Iterazione: 40 Thread_name = Thread-13205 (fun)
# Iterazione: 40 Thread_name = Thread-13206 (fun)
# Iterazione: 40 Thread_name = Thread-13207 (fun)
# Iterazione: 40 Thread_name = Thread-13208 (fun)
# Iterazione: 40 Thread_name = Thread-13209 (fun)
# Iterazione: 40 Thread_name = Thread-13210 (fun)
# Iterazione: 40 Thread_name = Thread-13211 (fun)
# Iterazione: 40 Thread_name = Thread-13212 (fun)
# Iterazione: 40 Thread_name = Thread-13213 (fun)
# Iterazione: 40 Thread_name = Thread-13214 (fun)
# Iterazione: 40 Thread_name = Thread-13215 (fun)
# Iterazione: 40 Thread_name = Thread-13216 (fun)
# Iterazione: 40 Thread_name = Thread-13217 (fun)
# Iterazione: 40 Thread_name = Thread-13218 (fun)
# Iterazione: 40 Thread_name = Thread-13219 (fun)
# Iterazione: 40 Thread_name = Thread-13220 (fun)
# Iterazione: 40 Thread_name = Thread-13221 (fun)
# Iterazione: 40 Thread_name = Thread-13222 (fun)
# Iterazione: 40 Thread_name = Thread-13223 (fun)
# Iterazione: 41 Thread_name = Thread-13224 (fun)
# Iterazione: 41 Thread_name = Thread-13225 (fun)
# Iterazione: 41 Thread_name = Thread-13226 (fun)
# Iterazione: 41 Thread_name = Thread-13227 (fun)
# Iterazione: 41 Thread_name = Thread-13228 (fun)
# Iterazione: 41 Thread_name = Thread-13229 (fun)
# Iterazione: 41 Thread_name = Thread-13230 (fun)
# Iterazione: 41 Thread_name = Thread-13231 (fun)
# Iterazione: 41 Thread_name = Thread-13232 (fun)
# Iterazione: 41 Thread_name = Thread-13233 (fun)
# Iterazione: 41 Thread_name = Thread-13234 (fun)
# Iterazione: 41 Thread_name = Thread-13235 (fun)
# Iterazione: 41 Thread_name = Thread-13236 (fun)
# Iterazione: 41 Thread_name = Thread-13237 (fun)
# Iterazione: 41 Thread_name = Thread-13238 (fun)
# Iterazione: 41 Thread_name = Thread-13239 (fun)
# Iterazione: 41 Thread_name = Thread-13240 (fun)
# Iterazione: 41 Thread_name = Thread-13241 (fun)
# Iterazione: 41 Thread_name = Thread-13242 (fun)
# Iterazione: 41 Thread_name = Thread-13243 (fun)
# Iterazione: 42 Thread_name = Thread-13244 (fun)
# Iterazione: 42 Thread_name = Thread-13245 (fun)
# Iterazione: 42 Thread_name = Thread-13246 (fun)
# Iterazione: 42 Thread_name = Thread-13247 (fun)
# Iterazione: 42 Thread_name = Thread-13248 (fun)
# Iterazione: 42 Thread_name = Thread-13249 (fun)
# Iterazione: 42 Thread_name = Thread-13250 (fun)
# Iterazione: 42 Thread_name = Thread-13251 (fun)
# Iterazione: 42 Thread_name = Thread-13252 (fun)
# Iterazione: 42 Thread_name = Thread-13253 (fun)
# Iterazione: 42 Thread_name = Thread-13254 (fun)
# Iterazione: 42 Thread_name = Thread-13255 (fun)
# Iterazione: 42 Thread_name = Thread-13256 (fun)
# Iterazione: 42 Thread_name = Thread-13257 (fun)
# Iterazione: 42 Thread_name = Thread-13258 (fun)
# Iterazione: 42 Thread_name = Thread-13259 (fun)
# Iterazione: 42 Thread_name = Thread-13260 (fun)
# Iterazione: 42 Thread_name = Thread-13261 (fun)
# Iterazione: 42 Thread_name = Thread-13262 (fun)
# Iterazione: 42 Thread_name = Thread-13263 (fun)
# Iterazione: 43 Thread_name = Thread-13264 (fun)
# Iterazione: 43 Thread_name = Thread-13265 (fun)
# Iterazione: 43 Thread_name = Thread-13266 (fun)
# Iterazione: 43 Thread_name = Thread-13267 (fun)
# Iterazione: 43 Thread_name = Thread-13268 (fun)
# Iterazione: 43 Thread_name = Thread-13269 (fun)
# Iterazione: 43 Thread_name = Thread-13270 (fun)
# Iterazione: 43 Thread_name = Thread-13271 (fun)
# Iterazione: 43 Thread_name = Thread-13272 (fun)
# Iterazione: 43 Thread_name = Thread-13273 (fun)
# Iterazione: 43 Thread_name = Thread-13274 (fun)
# Iterazione: 43 Thread_name = Thread-13275 (fun)
# Iterazione: 43 Thread_name = Thread-13276 (fun)
# Iterazione: 43 Thread_name = Thread-13277 (fun)
# Iterazione: 43 Thread_name = Thread-13278 (fun)
# Iterazione: 43 Thread_name = Thread-13279 (fun)
# Iterazione: 43 Thread_name = Thread-13280 (fun)
# Iterazione: 43 Thread_name = Thread-13281 (fun)
# Iterazione: 43 Thread_name = Thread-13282 (fun)
# Iterazione: 43 Thread_name = Thread-13283 (fun)
# Iterazione: 44 Thread_name = Thread-13284 (fun)
# Iterazione: 44 Thread_name = Thread-13285 (fun)
# Iterazione: 44 Thread_name = Thread-13286 (fun)
# Iterazione: 44 Thread_name = Thread-13287 (fun)
# Iterazione: 44 Thread_name = Thread-13288 (fun)
# Iterazione: 44 Thread_name = Thread-13289 (fun)
# Iterazione: 44 Thread_name = Thread-13290 (fun)
# Iterazione: 44 Thread_name = Thread-13291 (fun)
# Iterazione: 44 Thread_name = Thread-13292 (fun)
# Iterazione: 44 Thread_name = Thread-13293 (fun)
# Iterazione: 44 Thread_name = Thread-13294 (fun)
# Iterazione: 44 Thread_name = Thread-13295 (fun)
# Iterazione: 44 Thread_name = Thread-13296 (fun)
# Iterazione: 44 Thread_name = Thread-13297 (fun)
# Iterazione: 44 Thread_name = Thread-13298 (fun)
# Iterazione: 44 Thread_name = Thread-13299 (fun)
# Iterazione: 44 Thread_name = Thread-13300 (fun)
# Iterazione: 44 Thread_name = Thread-13301 (fun)
# Iterazione: 44 Thread_name = Thread-13302 (fun)
# Iterazione: 44 Thread_name = Thread-13303 (fun)
# Iterazione: 45 Thread_name = Thread-13304 (fun)
# Iterazione: 45 Thread_name = Thread-13305 (fun)
# Iterazione: 45 Thread_name = Thread-13306 (fun)
# Iterazione: 45 Thread_name = Thread-13307 (fun)
# Iterazione: 45 Thread_name = Thread-13308 (fun)
# Iterazione: 45 Thread_name = Thread-13309 (fun)
# Iterazione: 45 Thread_name = Thread-13310 (fun)
# Iterazione: 45 Thread_name = Thread-13311 (fun)
# Iterazione: 45 Thread_name = Thread-13312 (fun)
# Iterazione: 45 Thread_name = Thread-13313 (fun)
# Iterazione: 45 Thread_name = Thread-13314 (fun)
# Iterazione: 45 Thread_name = Thread-13315 (fun)
# Iterazione: 45 Thread_name = Thread-13316 (fun)
# Iterazione: 45 Thread_name = Thread-13317 (fun)
# Iterazione: 45 Thread_name = Thread-13318 (fun)
# Iterazione: 45 Thread_name = Thread-13319 (fun)
# Iterazione: 45 Thread_name = Thread-13320 (fun)
# Iterazione: 45 Thread_name = Thread-13321 (fun)
# Iterazione: 45 Thread_name = Thread-13322 (fun)
# Iterazione: 45 Thread_name = Thread-13323 (fun)
# Iterazione: 46 Thread_name = Thread-13324 (fun)
# Iterazione: 46 Thread_name = Thread-13325 (fun)
# Iterazione: 46 Thread_name = Thread-13326 (fun)
# Iterazione: 46 Thread_name = Thread-13327 (fun)
# Iterazione: 46 Thread_name = Thread-13328 (fun)
# Iterazione: 46 Thread_name = Thread-13329 (fun)
# Iterazione: 46 Thread_name = Thread-13330 (fun)
# Iterazione: 46 Thread_name = Thread-13331 (fun)
# Iterazione: 46 Thread_name = Thread-13332 (fun)
# Iterazione: 46 Thread_name = Thread-13333 (fun)
# Iterazione: 46 Thread_name = Thread-13334 (fun)
# Iterazione: 46 Thread_name = Thread-13335 (fun)
# Iterazione: 46 Thread_name = Thread-13336 (fun)
# Iterazione: 46 Thread_name = Thread-13337 (fun)
# Iterazione: 46 Thread_name = Thread-13338 (fun)
# Iterazione: 46 Thread_name = Thread-13339 (fun)
# Iterazione: 46 Thread_name = Thread-13340 (fun)
# Iterazione: 46 Thread_name = Thread-13341 (fun)
# Iterazione: 46 Thread_name = Thread-13342 (fun)
# Iterazione: 46 Thread_name = Thread-13343 (fun)
# Iterazione: 47 Thread_name = Thread-13344 (fun)
# Iterazione: 47 Thread_name = Thread-13345 (fun)
# Iterazione: 47 Thread_name = Thread-13346 (fun)
# Iterazione: 47 Thread_name = Thread-13347 (fun)
# Iterazione: 47 Thread_name = Thread-13348 (fun)
# Iterazione: 47 Thread_name = Thread-13349 (fun)
# Iterazione: 47 Thread_name = Thread-13350 (fun)
# Iterazione: 47 Thread_name = Thread-13351 (fun)
# Iterazione: 47 Thread_name = Thread-13352 (fun)
# Iterazione: 47 Thread_name = Thread-13353 (fun)
# Iterazione: 47 Thread_name = Thread-13354 (fun)
# Iterazione: 47 Thread_name = Thread-13355 (fun)
# Iterazione: 47 Thread_name = Thread-13356 (fun)
# Iterazione: 47 Thread_name = Thread-13357 (fun)
# Iterazione: 47 Thread_name = Thread-13358 (fun)
# Iterazione: 47 Thread_name = Thread-13359 (fun)
# Iterazione: 47 Thread_name = Thread-13360 (fun)
# Iterazione: 47 Thread_name = Thread-13361 (fun)
# Iterazione: 47 Thread_name = Thread-13362 (fun)
# Iterazione: 47 Thread_name = Thread-13363 (fun)
# Iterazione: 48 Thread_name = Thread-13364 (fun)
# Iterazione: 48 Thread_name = Thread-13365 (fun)
# Iterazione: 48 Thread_name = Thread-13366 (fun)
# Iterazione: 48 Thread_name = Thread-13367 (fun)
# Iterazione: 48 Thread_name = Thread-13368 (fun)
# Iterazione: 48 Thread_name = Thread-13369 (fun)
# Iterazione: 48 Thread_name = Thread-13370 (fun)
# Iterazione: 48 Thread_name = Thread-13371 (fun)
# Iterazione: 48 Thread_name = Thread-13372 (fun)
# Iterazione: 48 Thread_name = Thread-13373 (fun)
# Iterazione: 48 Thread_name = Thread-13374 (fun)
# Iterazione: 48 Thread_name = Thread-13375 (fun)
# Iterazione: 48 Thread_name = Thread-13376 (fun)
# Iterazione: 48 Thread_name = Thread-13377 (fun)
# Iterazione: 48 Thread_name = Thread-13378 (fun)
# Iterazione: 48 Thread_name = Thread-13379 (fun)
# Iterazione: 48 Thread_name = Thread-13380 (fun)
# Iterazione: 48 Thread_name = Thread-13381 (fun)
# Iterazione: 48 Thread_name = Thread-13382 (fun)
# Iterazione: 48 Thread_name = Thread-13383 (fun)
# Iterazione: 49 Thread_name = Thread-13384 (fun)
# Iterazione: 49 Thread_name = Thread-13385 (fun)
# Iterazione: 49 Thread_name = Thread-13386 (fun)
# Iterazione: 49 Thread_name = Thread-13387 (fun)
# Iterazione: 49 Thread_name = Thread-13388 (fun)
# Iterazione: 49 Thread_name = Thread-13389 (fun)
# Iterazione: 49 Thread_name = Thread-13390 (fun)
# Iterazione: 49 Thread_name = Thread-13391 (fun)
# Iterazione: 49 Thread_name = Thread-13392 (fun)
# Iterazione: 49 Thread_name = Thread-13393 (fun)
# Iterazione: 49 Thread_name = Thread-13394 (fun)
# Iterazione: 49 Thread_name = Thread-13395 (fun)
# Iterazione: 49 Thread_name = Thread-13396 (fun)
# Iterazione: 49 Thread_name = Thread-13397 (fun)
# Iterazione: 49 Thread_name = Thread-13398 (fun)
# Iterazione: 49 Thread_name = Thread-13399 (fun)
# Iterazione: 49 Thread_name = Thread-13400 (fun)
# Iterazione: 49 Thread_name = Thread-13401 (fun)
# Iterazione: 49 Thread_name = Thread-13402 (fun)
# Iterazione: 49 Thread_name = Thread-13403 (fun)
# Iterazione: 50 Thread_name = Thread-13404 (fun)
# Iterazione: 50 Thread_name = Thread-13405 (fun)
# Iterazione: 50 Thread_name = Thread-13406 (fun)
# Iterazione: 50 Thread_name = Thread-13407 (fun)
# ...
# Iterazione: 603 Thread_name = Thread-24478 (fun)
# Iterazione: 603 Thread_name = Thread-24479 (fun)
# Iterazione: 603 Thread_name = Thread-24480 (fun)
# Iterazione: 603 Thread_name = Thread-24481 (fun)
# Iterazione: 603 Thread_name = Thread-24482 (fun)
# Iterazione: 603 Thread_name = Thread-24483 (fun)
# Iterazione: 604 Thread_name = Thread-24484 (fun)
# Iterazione: 604 Thread_name = Thread-24485 (fun)
# Iterazione: 604 Thread_name = Thread-24486 (fun)
# Iterazione: 604 Thread_name = Thread-24487 (fun)
# Iterazione: 604 Thread_name = Thread-24488 (fun)
# Iterazione: 604 Thread_name = Thread-24489 (fun)
# Iterazione: 604 Thread_name = Thread-24490 (fun)
# Iterazione: 604 Thread_name = Thread-24491 (fun)
# Iterazione: 604 Thread_name = Thread-24492 (fun)
# Iterazione: 604 Thread_name = Thread-24493 (fun)
# Iterazione: 604 Thread_name = Thread-24494 (fun)
# Iterazione: 604 Thread_name = Thread-24495 (fun)
# Iterazione: 604 Thread_name = Thread-24496 (fun)
# Iterazione: 604 Thread_name = Thread-24497 (fun)
# Iterazione: 604 Thread_name = Thread-24498 (fun)
# Iterazione: 604 Thread_name = Thread-24499 (fun)
# Iterazione: 604 Thread_name = Thread-24500 (fun)
# Iterazione: 604 Thread_name = Thread-24501 (fun)
# Iterazione: 604 Thread_name = Thread-24502 (fun)
# Iterazione: 604 Thread_name = Thread-24503 (fun)
# Iterazione: 605 Thread_name = Thread-24504 (fun)
# Iterazione: 605 Thread_name = Thread-24505 (fun)
# Iterazione: 605 Thread_name = Thread-24506 (fun)
# Iterazione: 605 Thread_name = Thread-24507 (fun)
# Iterazione: 605 Thread_name = Thread-24508 (fun)
# Iterazione: 605 Thread_name = Thread-24509 (fun)
# Iterazione: 605 Thread_name = Thread-24510 (fun)
# Iterazione: 605 Thread_name = Thread-24511 (fun)
# Iterazione: 605 Thread_name = Thread-24512 (fun)
# Iterazione: 605 Thread_name = Thread-24513 (fun)
# Iterazione: 605 Thread_name = Thread-24514 (fun)
# Iterazione: 605 Thread_name = Thread-24515 (fun)
# Iterazione: 605 Thread_name = Thread-24516 (fun)
# Iterazione: 605 Thread_name = Thread-24517 (fun)
# Iterazione: 605 Thread_name = Thread-24518 (fun)
# Iterazione: 605 Thread_name = Thread-24519 (fun)
# Iterazione: 605 Thread_name = Thread-24520 (fun)
# Iterazione: 605 Thread_name = Thread-24521 (fun)
# Iterazione: 605 Thread_name = Thread-24522 (fun)
# Iterazione: 605 Thread_name = Thread-24523 (fun)
# Iterazione: 606 Thread_name = Thread-24524 (fun)
# Iterazione: 606 Thread_name = Thread-24525 (fun)
# Iterazione: 606 Thread_name = Thread-24526 (fun)
# Iterazione: 606 Thread_name = Thread-24527 (fun)
# Iterazione: 606 Thread_name = Thread-24528 (fun)
# Iterazione: 606 Thread_name = Thread-24529 (fun)
# Iterazione: 606 Thread_name = Thread-24530 (fun)
# Iterazione: 606 Thread_name = Thread-24531 (fun)
# Iterazione: 606 Thread_name = Thread-24532 (fun)
# Iterazione: 606 Thread_name = Thread-24533 (fun)
# Iterazione: 606 Thread_name = Thread-24534 (fun)
# Iterazione: 606 Thread_name = Thread-24535 (fun)
# Iterazione: 606 Thread_name = Thread-24536 (fun)
# Iterazione: 606 Thread_name = Thread-24537 (fun)
# Iterazione: 606 Thread_name = Thread-24538 (fun)
# Iterazione: 606 Thread_name = Thread-24539 (fun)
# Iterazione: 606 Thread_name = Thread-24540 (fun)
# Iterazione: 606 Thread_name = Thread-24541 (fun)
# Iterazione: 606 Thread_name = Thread-24542 (fun)
# Iterazione: 606 Thread_name = Thread-24543 (fun)
# Iterazione: 607 Thread_name = Thread-24544 (fun)
# Iterazione: 607 Thread_name = Thread-24545 (fun)
# Iterazione: 607 Thread_name = Thread-24546 (fun)
# Iterazione: 607 Thread_name = Thread-24547 (fun)
# Iterazione: 607 Thread_name = Thread-24548 (fun)
# Iterazione: 607 Thread_name = Thread-24549 (fun)
# Iterazione: 607 Thread_name = Thread-24550 (fun)
# Iterazione: 607 Thread_name = Thread-24551 (fun)
# Iterazione: 607 Thread_name = Thread-24552 (fun)
# Iterazione: 607 Thread_name = Thread-24553 (fun)
# Iterazione: 607 Thread_name = Thread-24554 (fun)
# Iterazione: 607 Thread_name = Thread-24555 (fun)
# Iterazione: 607 Thread_name = Thread-24556 (fun)
# Iterazione: 607 Thread_name = Thread-24557 (fun)
# Iterazione: 607 Thread_name = Thread-24558 (fun)
# Iterazione: 607 Thread_name = Thread-24559 (fun)
# Iterazione: 607 Thread_name = Thread-24560 (fun)
# Iterazione: 607 Thread_name = Thread-24561 (fun)
# Iterazione: 607 Thread_name = Thread-24562 (fun)
# Iterazione: 607 Thread_name = Thread-24563 (fun)
# Iterazione: 608 Thread_name = Thread-24564 (fun)
# Iterazione: 608 Thread_name = Thread-24565 (fun)
# Iterazione: 608 Thread_name = Thread-24566 (fun)
# Iterazione: 608 Thread_name = Thread-24567 (fun)
# Iterazione: 608 Thread_name = Thread-24568 (fun)
# Iterazione: 608 Thread_name = Thread-24569 (fun)
# Iterazione: 608 Thread_name = Thread-24570 (fun)
# Iterazione: 608 Thread_name = Thread-24571 (fun)
# Iterazione: 608 Thread_name = Thread-24572 (fun)
# Iterazione: 608 Thread_name = Thread-24573 (fun)
# Iterazione: 608 Thread_name = Thread-24574 (fun)
# Iterazione: 608 Thread_name = Thread-24575 (fun)
# Iterazione: 608 Thread_name = Thread-24576 (fun)
# Iterazione: 608 Thread_name = Thread-24577 (fun)
# Iterazione: 608 Thread_name = Thread-24578 (fun)
# Iterazione: 608 Thread_name = Thread-24579 (fun)
# Iterazione: 608 Thread_name = Thread-24580 (fun)
# Iterazione: 608 Thread_name = Thread-24581 (fun)
# Iterazione: 608 Thread_name = Thread-24582 (fun)
# Iterazione: 608 Thread_name = Thread-24583 (fun)
# Iterazione: 609 Thread_name = Thread-24584 (fun)
# Iterazione: 609 Thread_name = Thread-24585 (fun)
# Iterazione: 609 Thread_name = Thread-24586 (fun)
# Iterazione: 609 Thread_name = Thread-24587 (fun)
# Iterazione: 609 Thread_name = Thread-24588 (fun)
# Iterazione: 609 Thread_name = Thread-24589 (fun)
# Iterazione: 609 Thread_name = Thread-24590 (fun)
# Iterazione: 609 Thread_name = Thread-24591 (fun)
# Iterazione: 609 Thread_name = Thread-24592 (fun)
# Iterazione: 609 Thread_name = Thread-24593 (fun)
# Iterazione: 609 Thread_name = Thread-24594 (fun)
# Iterazione: 609 Thread_name = Thread-24595 (fun)
# Iterazione: 609 Thread_name = Thread-24596 (fun)
# Iterazione: 609 Thread_name = Thread-24597 (fun)
# Iterazione: 609 Thread_name = Thread-24598 (fun)
# Iterazione: 609 Thread_name = Thread-24599 (fun)
# Iterazione: 609 Thread_name = Thread-24600 (fun)
# Iterazione: 609 Thread_name = Thread-24601 (fun)
# Iterazione: 609 Thread_name = Thread-24602 (fun)
# Iterazione: 609 Thread_name = Thread-24603 (fun)
# Iterazione: 610 Thread_name = Thread-24604 (fun)
# Iterazione: 610 Thread_name = Thread-24605 (fun)
# Iterazione: 610 Thread_name = Thread-24606 (fun)
# Iterazione: 610 Thread_name = Thread-24607 (fun)
# Iterazione: 610 Thread_name = Thread-24608 (fun)
# Iterazione: 610 Thread_name = Thread-24609 (fun)
# Iterazione: 610 Thread_name = Thread-24610 (fun)
# Iterazione: 610 Thread_name = Thread-24611 (fun)
# Iterazione: 610 Thread_name = Thread-24612 (fun)
# Iterazione: 610 Thread_name = Thread-24613 (fun)
# Iterazione: 610 Thread_name = Thread-24614 (fun)
# Iterazione: 610 Thread_name = Thread-24615 (fun)
# Iterazione: 610 Thread_name = Thread-24616 (fun)
# Iterazione: 610 Thread_name = Thread-24617 (fun)
# Iterazione: 610 Thread_name = Thread-24618 (fun)
# Iterazione: 610 Thread_name = Thread-24619 (fun)
# Iterazione: 610 Thread_name = Thread-24620 (fun)
# Iterazione: 610 Thread_name = Thread-24621 (fun)
# Iterazione: 610 Thread_name = Thread-24622 (fun)
# Iterazione: 610 Thread_name = Thread-24623 (fun)
# Iterazione: 611 Thread_name = Thread-24624 (fun)
# Iterazione: 611 Thread_name = Thread-24625 (fun)
# Iterazione: 611 Thread_name = Thread-24626 (fun)
# Iterazione: 611 Thread_name = Thread-24627 (fun)
# Iterazione: 611 Thread_name = Thread-24628 (fun)
# Iterazione: 611 Thread_name = Thread-24629 (fun)
# Iterazione: 611 Thread_name = Thread-24630 (fun)
# Iterazione: 611 Thread_name = Thread-24631 (fun)
# Iterazione: 611 Thread_name = Thread-24632 (fun)
# Iterazione: 611 Thread_name = Thread-24633 (fun)
# Iterazione: 611 Thread_name = Thread-24634 (fun)
# Iterazione: 611 Thread_name = Thread-24635 (fun)
# Iterazione: 611 Thread_name = Thread-24636 (fun)
# Iterazione: 611 Thread_name = Thread-24637 (fun)
# Iterazione: 611 Thread_name = Thread-24638 (fun)
# Iterazione: 611 Thread_name = Thread-24639 (fun)
# Iterazione: 611 Thread_name = Thread-24640 (fun)
# Iterazione: 611 Thread_name = Thread-24641 (fun)
# Iterazione: 611 Thread_name = Thread-24642 (fun)
# Iterazione: 611 Thread_name = Thread-24643 (fun)
# Iterazione: 612 Thread_name = Thread-24644 (fun)
# Iterazione: 612 Thread_name = Thread-24645 (fun)
# Iterazione: 612 Thread_name = Thread-24646 (fun)
# Iterazione: 612 Thread_name = Thread-24647 (fun)
# Iterazione: 612 Thread_name = Thread-24648 (fun)
# Iterazione: 612 Thread_name = Thread-24649 (fun)
# Iterazione: 612 Thread_name = Thread-24650 (fun)
# Iterazione: 612 Thread_name = Thread-24651 (fun)
# Iterazione: 612 Thread_name = Thread-24652 (fun)
# Iterazione: 612 Thread_name = Thread-24653 (fun)
# Iterazione: 612 Thread_name = Thread-24654 (fun)
# Iterazione: 612 Thread_name = Thread-24655 (fun)
# Iterazione: 612 Thread_name = Thread-24656 (fun)
# Iterazione: 612 Thread_name = Thread-24657 (fun)
# Iterazione: 612 Thread_name = Thread-24658 (fun)
# Iterazione: 612 Thread_name = Thread-24659 (fun)
# Iterazione: 612 Thread_name = Thread-24660 (fun)
# Iterazione: 612 Thread_name = Thread-24661 (fun)
# Iterazione: 612 Thread_name = Thread-24662 (fun)
# Iterazione: 612 Thread_name = Thread-24663 (fun)
# Iterazione: 613 Thread_name = Thread-24664 (fun)
# Iterazione: 613 Thread_name = Thread-24665 (fun)
# Iterazione: 613 Thread_name = Thread-24666 (fun)
# Iterazione: 613 Thread_name = Thread-24667 (fun)
# Iterazione: 613 Thread_name = Thread-24668 (fun)
# Iterazione: 613 Thread_name = Thread-24669 (fun)
# Iterazione: 613 Thread_name = Thread-24670 (fun)
# Iterazione: 613 Thread_name = Thread-24671 (fun)
# Iterazione: 613 Thread_name = Thread-24672 (fun)
# Iterazione: 613 Thread_name = Thread-24673 (fun)
# Iterazione: 613 Thread_name = Thread-24674 (fun)
# Iterazione: 613 Thread_name = Thread-24675 (fun)
# Iterazione: 613 Thread_name = Thread-24676 (fun)
# Iterazione: 613 Thread_name = Thread-24677 (fun)
# Iterazione: 613 Thread_name = Thread-24678 (fun)
# Iterazione: 613 Thread_name = Thread-24679 (fun)
# Iterazione: 613 Thread_name = Thread-24680 (fun)
# Iterazione: 613 Thread_name = Thread-24681 (fun)
# Iterazione: 613 Thread_name = Thread-24682 (fun)
# Iterazione: 613 Thread_name = Thread-24683 (fun)
# Iterazione: 614 Thread_name = Thread-24684 (fun)
# Iterazione: 614 Thread_name = Thread-24685 (fun)
# Iterazione: 614 Thread_name = Thread-24686 (fun)
# Iterazione: 614 Thread_name = Thread-24687 (fun)
# Iterazione: 614 Thread_name = Thread-24688 (fun)
# Iterazione: 614 Thread_name = Thread-24689 (fun)
# Iterazione: 614 Thread_name = Thread-24690 (fun)
# Iterazione: 614 Thread_name = Thread-24691 (fun)
# Iterazione: 614 Thread_name = Thread-24692 (fun)
# Iterazione: 614 Thread_name = Thread-24693 (fun)
# Iterazione: 614 Thread_name = Thread-24694 (fun)
# Iterazione: 614 Thread_name = Thread-24695 (fun)
# Iterazione: 614 Thread_name = Thread-24696 (fun)
# Iterazione: 614 Thread_name = Thread-24697 (fun)
# Iterazione: 614 Thread_name = Thread-24698 (fun)
# Iterazione: 614 Thread_name = Thread-24699 (fun)
# Iterazione: 614 Thread_name = Thread-24700 (fun)
# Iterazione: 614 Thread_name = Thread-24701 (fun)
# Iterazione: 614 Thread_name = Thread-24702 (fun)
# Iterazione: 614 Thread_name = Thread-24703 (fun)
# Iterazione: 615 Thread_name = Thread-24704 (fun)
# Iterazione: 615 Thread_name = Thread-24705 (fun)
# Iterazione: 615 Thread_name = Thread-24706 (fun)
# Iterazione: 615 Thread_name = Thread-24707 (fun)
# Iterazione: 615 Thread_name = Thread-24708 (fun)
# Iterazione: 615 Thread_name = Thread-24709 (fun)
# Iterazione: 615 Thread_name = Thread-24710 (fun)
# Iterazione: 615 Thread_name = Thread-24711 (fun)
# Iterazione: 615 Thread_name = Thread-24712 (fun)
# Iterazione: 615 Thread_name = Thread-24713 (fun)
# Iterazione: 615 Thread_name = Thread-24714 (fun)
# Iterazione: 615 Thread_name = Thread-24715 (fun)
# Iterazione: 615 Thread_name = Thread-24716 (fun)
# Iterazione: 615 Thread_name = Thread-24717 (fun)
# Iterazione: 615 Thread_name = Thread-24718 (fun)
# Iterazione: 615 Thread_name = Thread-24719 (fun)
# Iterazione: 615 Thread_name = Thread-24720 (fun)
# Iterazione: 615 Thread_name = Thread-24721 (fun)
# Iterazione: 615 Thread_name = Thread-24722 (fun)
# Iterazione: 615 Thread_name = Thread-24723 (fun)
# Iterazione: 616 Thread_name = Thread-24724 (fun)
# Iterazione: 616 Thread_name = Thread-24725 (fun)
# Iterazione: 616 Thread_name = Thread-24726 (fun)
# Iterazione: 616 Thread_name = Thread-24727 (fun)
# Iterazione: 616 Thread_name = Thread-24728 (fun)
# Iterazione: 616 Thread_name = Thread-24729 (fun)
# Iterazione: 616 Thread_name = Thread-24730 (fun)
# Iterazione: 616 Thread_name = Thread-24731 (fun)
# Iterazione: 616 Thread_name = Thread-24732 (fun)
# Iterazione: 616 Thread_name = Thread-24733 (fun)
# Iterazione: 616 Thread_name = Thread-24734 (fun)
# Iterazione: 616 Thread_name = Thread-24735 (fun)
# Iterazione: 616 Thread_name = Thread-24736 (fun)
# Iterazione: 616 Thread_name = Thread-24737 (fun)
# Iterazione: 616 Thread_name = Thread-24738 (fun)
# Iterazione: 616 Thread_name = Thread-24739 (fun)
# Iterazione: 616 Thread_name = Thread-24740 (fun)
# Iterazione: 616 Thread_name = Thread-24741 (fun)
# Iterazione: 616 Thread_name = Thread-24742 (fun)
# Iterazione: 616 Thread_name = Thread-24743 (fun)
# Iterazione: 617 Thread_name = Thread-24744 (fun)
# Iterazione: 617 Thread_name = Thread-24745 (fun)
# Iterazione: 617 Thread_name = Thread-24746 (fun)
# Iterazione: 617 Thread_name = Thread-24747 (fun)
# Iterazione: 617 Thread_name = Thread-24748 (fun)
# Iterazione: 617 Thread_name = Thread-24749 (fun)
# Iterazione: 617 Thread_name = Thread-24750 (fun)
# Iterazione: 617 Thread_name = Thread-24751 (fun)
# Iterazione: 617 Thread_name = Thread-24752 (fun)
# Iterazione: 617 Thread_name = Thread-24753 (fun)
# Iterazione: 617 Thread_name = Thread-24754 (fun)
# Iterazione: 617 Thread_name = Thread-24755 (fun)
# Iterazione: 617 Thread_name = Thread-24756 (fun)
# Iterazione: 617 Thread_name = Thread-24757 (fun)
# Iterazione: 617 Thread_name = Thread-24758 (fun)
# Iterazione: 617 Thread_name = Thread-24759 (fun)
# Iterazione: 617 Thread_name = Thread-24760 (fun)
# Iterazione: 617 Thread_name = Thread-24761 (fun)
# Iterazione: 617 Thread_name = Thread-24762 (fun)
# Iterazione: 617 Thread_name = Thread-24763 (fun)
# Iterazione: 618 Thread_name = Thread-24764 (fun)
# Iterazione: 618 Thread_name = Thread-24765 (fun)
# Iterazione: 618 Thread_name = Thread-24766 (fun)
# Iterazione: 618 Thread_name = Thread-24767 (fun)
# Iterazione: 618 Thread_name = Thread-24768 (fun)
# Iterazione: 618 Thread_name = Thread-24769 (fun)
# Iterazione: 618 Thread_name = Thread-24770 (fun)
# Iterazione: 618 Thread_name = Thread-24771 (fun)
# Iterazione: 618 Thread_name = Thread-24772 (fun)
# Iterazione: 618 Thread_name = Thread-24773 (fun)
# Iterazione: 618 Thread_name = Thread-24774 (fun)
# Iterazione: 618 Thread_name = Thread-24775 (fun)
# Iterazione: 618 Thread_name = Thread-24776 (fun)
# Iterazione: 618 Thread_name = Thread-24777 (fun)
# Iterazione: 618 Thread_name = Thread-24778 (fun)
# Iterazione: 618 Thread_name = Thread-24779 (fun)
# Iterazione: 618 Thread_name = Thread-24780 (fun)
# Iterazione: 618 Thread_name = Thread-24781 (fun)
# Iterazione: 618 Thread_name = Thread-24782 (fun)
# Iterazione: 618 Thread_name = Thread-24783 (fun)
# Iterazione: 619 Thread_name = Thread-24784 (fun)
# Iterazione: 619 Thread_name = Thread-24785 (fun)
# Iterazione: 619 Thread_name = Thread-24786 (fun)
# Iterazione: 619 Thread_name = Thread-24787 (fun)
# Iterazione: 619 Thread_name = Thread-24788 (fun)
# Iterazione: 619 Thread_name = Thread-24789 (fun)
# Iterazione: 619 Thread_name = Thread-24790 (fun)
# Iterazione: 619 Thread_name = Thread-24791 (fun)
# Iterazione: 619 Thread_name = Thread-24792 (fun)
# Iterazione: 619 Thread_name = Thread-24793 (fun)
# Iterazione: 619 Thread_name = Thread-24794 (fun)
# Iterazione: 619 Thread_name = Thread-24795 (fun)
# Iterazione: 619 Thread_name = Thread-24796 (fun)
# Iterazione: 619 Thread_name = Thread-24797 (fun)
# Iterazione: 619 Thread_name = Thread-24798 (fun)
# Iterazione: 619 Thread_name = Thread-24799 (fun)
# Iterazione: 619 Thread_name = Thread-24800 (fun)
# Iterazione: 619 Thread_name = Thread-24801 (fun)
# Iterazione: 619 Thread_name = Thread-24802 (fun)
# Iterazione: 619 Thread_name = Thread-24803 (fun)

# %%
df = pd.DataFrame(outputs)
df = df.transpose()
df.columns=headers

# %%
if not os.path.isfile('server.csv'):
   df.to_csv('server.csv',index=False)
else: 
   df.to_csv('server.csv', index = False,mode='a', header=False)
