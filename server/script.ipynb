# %%
import threading
import time
import os 
import pandas as pd
from datetime import datetime
import subprocess

# %%
apache_pid = os.popen("ps aux | grep -i apache | head -1 | awk ' { print $2 } ' ").read().replace("\n",'')
print(f"Apache pid : {apache_pid}")
# Out:
# Apache pid : 1283

# %%
headers = ["VmPeak","VmRSS","VmSize","VmHWM","VmPTE","Threads","MemFree","Buffers","Cached","Active","Inactive","Dirty","Writeback","AnonPages","Mapped","Slab","PageTables","Committed_AS","NumOfAllocFH","proc_fd","label"]

# %%
VmPeak= subprocess.check_output("grep VmPeak /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmRSS = subprocess.check_output("grep VmRSS /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmSize = subprocess.check_output("grep VmSize /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmHWM = subprocess.check_output("grep VmHWM/ proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
VmPTE = subprocess.check_output("grep VmPTE /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
Threads = subprocess.check_output("grep Threads /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",cwd = "/",shell=True).decode('utf-8')
MemFree = subprocess.check_output("grep MemFree /proc/meminfo | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Buffers = subprocess.check_output("grep Buffers /proc/meminfo | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Cached = subprocess.check_output("grep Cached /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Active = subprocess.check_output("grep Active /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Inactive = subprocess.check_output("grep Inactive /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Dirty = subprocess.check_output("grep Dirty /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Writeback = subprocess.check_output("grep Writeback /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
AnonPages = subprocess.check_output("grep AnonPages /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Mapped = subprocess.check_output("grep Mapped /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Slab = subprocess.check_output("grep Slab /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
PageTables =  subprocess.check_output("grep PageTables /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
Committed_AS =  subprocess.check_output("grep Committed_AS /proc/meminfo |  head -1 | awk ' { print $2}'",cwd = "/",shell=True).decode('utf-8')
NumOfAllocFH = subprocess.check_output("head -1 /proc/sys/fs/file-nr | awk ' {print $1}' ",cwd = "/",shell=True).decode('utf-8')
proc_fd = subprocess.check_output("cat /proc/sys/fs/file-nr | awk ' { print $1 } '",cwd = "/",shell=True).decode('utf-8')

# %%
commands = [
    "grep VmPeak /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmRSS /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmSize /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmHWM/ proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep VmPTE /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep Threads /proc/"+str(apache_pid)+"/status | awk ' { print $2}' ",
    "grep MemFree /proc/meminfo | awk ' { print $2}'",
    "grep Buffers /proc/meminfo | awk ' { print $2}'",
    "grep Cached /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Active /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Inactive /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Dirty /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Writeback /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep AnonPages /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Mapped /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Slab /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep PageTables /proc/meminfo |  head -1 | awk ' { print $2}'",
    "grep Committed_AS /proc/meminfo |  head -1 | awk ' { print $2}'",
    "head -1 /proc/sys/fs/file-nr | awk ' {print $1}' ",
    "cat /proc/sys/fs/file-nr | awk ' { print $1 } '"
]

# %%
outputs = [[] for _ in range(len(commands)+1)] #the last one is for the timestamp

# %%
def fun(i):
    val = subprocess.check_output(commands[i],cwd = "/",shell=True).decode('utf-8').replace("\n",'')
    outputs[i].append(val)

# %%
n_it = 620
for it in range(n_it):
    threads = [threading.Thread(target = fun,args = (i,))for i in range(len(commands))]
    outputs[len(commands)].append(str(datetime.now())[-15:-7])
    for thread in threads:
        thread.start()
        print(f'Iterazione: {it} Thread_name = {thread.name}')
    thread.join()
    time.sleep(1)
# Out:
# Iterazione: 0 Thread_name = Thread-4 (fun)
# Iterazione: 0 Thread_name = Thread-5 (fun)
# Iterazione: 0 Thread_name = Thread-6 (fun)
# Iterazione: 0 Thread_name = Thread-7 (fun)
# Iterazione: 0 Thread_name = Thread-8 (fun)
# Iterazione: 0 Thread_name = Thread-9 (fun)
# Iterazione: 0 Thread_name = Thread-10 (fun)
# Iterazione: 0 Thread_name = Thread-11 (fun)
# Iterazione: 0 Thread_name = Thread-12 (fun)
# Iterazione: 0 Thread_name = Thread-13 (fun)
# Iterazione: 0 Thread_name = Thread-14 (fun)
# Iterazione: 0 Thread_name = Thread-15 (fun)
# Iterazione: 0 Thread_name = Thread-16 (fun)
# Iterazione: 0 Thread_name = Thread-17 (fun)
# Iterazione: 0 Thread_name = Thread-18 (fun)
# Iterazione: 0 Thread_name = Thread-19 (fun)
# Iterazione: 0 Thread_name = Thread-20 (fun)
# Iterazione: 0 Thread_name = Thread-21 (fun)
# Iterazione: 0 Thread_name = Thread-22 (fun)
# Iterazione: 0 Thread_name = Thread-23 (fun)
# Iterazione: 1 Thread_name = Thread-24 (fun)
# Iterazione: 1 Thread_name = Thread-25 (fun)
# Iterazione: 1 Thread_name = Thread-26 (fun)
# Iterazione: 1 Thread_name = Thread-27 (fun)
# Iterazione: 1 Thread_name = Thread-28 (fun)
# Iterazione: 1 Thread_name = Thread-29 (fun)
# Iterazione: 1 Thread_name = Thread-30 (fun)
# Iterazione: 1 Thread_name = Thread-31 (fun)
# Iterazione: 1 Thread_name = Thread-32 (fun)
# Iterazione: 1 Thread_name = Thread-33 (fun)
# Iterazione: 1 Thread_name = Thread-34 (fun)
# Iterazione: 1 Thread_name = Thread-35 (fun)
# Iterazione: 1 Thread_name = Thread-36 (fun)
# Iterazione: 1 Thread_name = Thread-37 (fun)
# Iterazione: 1 Thread_name = Thread-38 (fun)
# Iterazione: 1 Thread_name = Thread-39 (fun)
# Iterazione: 1 Thread_name = Thread-40 (fun)
# Iterazione: 1 Thread_name = Thread-41 (fun)
# Iterazione: 1 Thread_name = Thread-42 (fun)
# Iterazione: 1 Thread_name = Thread-43 (fun)
# Iterazione: 2 Thread_name = Thread-44 (fun)
# Iterazione: 2 Thread_name = Thread-45 (fun)
# Iterazione: 2 Thread_name = Thread-46 (fun)
# Iterazione: 2 Thread_name = Thread-47 (fun)
# Iterazione: 2 Thread_name = Thread-48 (fun)
# Iterazione: 2 Thread_name = Thread-49 (fun)
# Iterazione: 2 Thread_name = Thread-50 (fun)
# Iterazione: 2 Thread_name = Thread-51 (fun)
# Iterazione: 2 Thread_name = Thread-52 (fun)
# Iterazione: 2 Thread_name = Thread-53 (fun)
# Iterazione: 2 Thread_name = Thread-54 (fun)
# Iterazione: 2 Thread_name = Thread-55 (fun)
# Iterazione: 2 Thread_name = Thread-56 (fun)
# Iterazione: 2 Thread_name = Thread-57 (fun)
# Iterazione: 2 Thread_name = Thread-58 (fun)
# Iterazione: 2 Thread_name = Thread-59 (fun)
# Iterazione: 2 Thread_name = Thread-60 (fun)
# Iterazione: 2 Thread_name = Thread-61 (fun)
# Iterazione: 2 Thread_name = Thread-62 (fun)
# Iterazione: 2 Thread_name = Thread-63 (fun)
# Iterazione: 3 Thread_name = Thread-64 (fun)
# Iterazione: 3 Thread_name = Thread-65 (fun)
# Iterazione: 3 Thread_name = Thread-66 (fun)
# Iterazione: 3 Thread_name = Thread-67 (fun)
# Iterazione: 3 Thread_name = Thread-68 (fun)
# Iterazione: 3 Thread_name = Thread-69 (fun)
# Iterazione: 3 Thread_name = Thread-70 (fun)
# Iterazione: 3 Thread_name = Thread-71 (fun)
# Iterazione: 3 Thread_name = Thread-72 (fun)
# Iterazione: 3 Thread_name = Thread-73 (fun)
# Iterazione: 3 Thread_name = Thread-74 (fun)
# Iterazione: 3 Thread_name = Thread-75 (fun)
# Iterazione: 3 Thread_name = Thread-76 (fun)
# Iterazione: 3 Thread_name = Thread-77 (fun)
# Iterazione: 3 Thread_name = Thread-78 (fun)
# Iterazione: 3 Thread_name = Thread-79 (fun)
# Iterazione: 3 Thread_name = Thread-80 (fun)
# Iterazione: 3 Thread_name = Thread-81 (fun)
# Iterazione: 3 Thread_name = Thread-82 (fun)
# Iterazione: 3 Thread_name = Thread-83 (fun)
# Iterazione: 4 Thread_name = Thread-84 (fun)
# Iterazione: 4 Thread_name = Thread-85 (fun)
# Iterazione: 4 Thread_name = Thread-86 (fun)
# Iterazione: 4 Thread_name = Thread-87 (fun)
# Iterazione: 4 Thread_name = Thread-88 (fun)
# Iterazione: 4 Thread_name = Thread-89 (fun)
# Iterazione: 4 Thread_name = Thread-90 (fun)
# Iterazione: 4 Thread_name = Thread-91 (fun)
# Iterazione: 4 Thread_name = Thread-92 (fun)
# Iterazione: 4 Thread_name = Thread-93 (fun)
# Iterazione: 4 Thread_name = Thread-94 (fun)
# Iterazione: 4 Thread_name = Thread-95 (fun)
# Iterazione: 4 Thread_name = Thread-96 (fun)
# Iterazione: 4 Thread_name = Thread-97 (fun)
# Iterazione: 4 Thread_name = Thread-98 (fun)
# Iterazione: 4 Thread_name = Thread-99 (fun)
# Iterazione: 4 Thread_name = Thread-100 (fun)
# Iterazione: 4 Thread_name = Thread-101 (fun)
# Iterazione: 4 Thread_name = Thread-102 (fun)
# Iterazione: 4 Thread_name = Thread-103 (fun)
# Iterazione: 5 Thread_name = Thread-104 (fun)
# Iterazione: 5 Thread_name = Thread-105 (fun)
# Iterazione: 5 Thread_name = Thread-106 (fun)
# Iterazione: 5 Thread_name = Thread-107 (fun)
# Iterazione: 5 Thread_name = Thread-108 (fun)
# Iterazione: 5 Thread_name = Thread-109 (fun)
# Iterazione: 5 Thread_name = Thread-110 (fun)
# Iterazione: 5 Thread_name = Thread-111 (fun)
# Iterazione: 5 Thread_name = Thread-112 (fun)
# Iterazione: 5 Thread_name = Thread-113 (fun)
# Iterazione: 5 Thread_name = Thread-114 (fun)
# Iterazione: 5 Thread_name = Thread-115 (fun)
# Iterazione: 5 Thread_name = Thread-116 (fun)
# Iterazione: 5 Thread_name = Thread-117 (fun)
# Iterazione: 5 Thread_name = Thread-118 (fun)
# Iterazione: 5 Thread_name = Thread-119 (fun)
# Iterazione: 5 Thread_name = Thread-120 (fun)
# Iterazione: 5 Thread_name = Thread-121 (fun)
# Iterazione: 5 Thread_name = Thread-122 (fun)
# Iterazione: 5 Thread_name = Thread-123 (fun)
# Iterazione: 6 Thread_name = Thread-124 (fun)
# Iterazione: 6 Thread_name = Thread-125 (fun)
# Iterazione: 6 Thread_name = Thread-126 (fun)
# Iterazione: 6 Thread_name = Thread-127 (fun)
# Iterazione: 6 Thread_name = Thread-128 (fun)
# Iterazione: 6 Thread_name = Thread-129 (fun)
# Iterazione: 6 Thread_name = Thread-130 (fun)
# Iterazione: 6 Thread_name = Thread-131 (fun)
# Iterazione: 6 Thread_name = Thread-132 (fun)
# Iterazione: 6 Thread_name = Thread-133 (fun)
# Iterazione: 6 Thread_name = Thread-134 (fun)
# Iterazione: 6 Thread_name = Thread-135 (fun)
# Iterazione: 6 Thread_name = Thread-136 (fun)
# Iterazione: 6 Thread_name = Thread-137 (fun)
# Iterazione: 6 Thread_name = Thread-138 (fun)
# Iterazione: 6 Thread_name = Thread-139 (fun)
# Iterazione: 6 Thread_name = Thread-140 (fun)
# Iterazione: 6 Thread_name = Thread-141 (fun)
# Iterazione: 6 Thread_name = Thread-142 (fun)
# Iterazione: 6 Thread_name = Thread-143 (fun)
# Iterazione: 7 Thread_name = Thread-144 (fun)
# Iterazione: 7 Thread_name = Thread-145 (fun)
# Iterazione: 7 Thread_name = Thread-146 (fun)
# Iterazione: 7 Thread_name = Thread-147 (fun)
# Iterazione: 7 Thread_name = Thread-148 (fun)
# Iterazione: 7 Thread_name = Thread-149 (fun)
# Iterazione: 7 Thread_name = Thread-150 (fun)
# Iterazione: 7 Thread_name = Thread-151 (fun)
# Iterazione: 7 Thread_name = Thread-152 (fun)
# Iterazione: 7 Thread_name = Thread-153 (fun)
# Iterazione: 7 Thread_name = Thread-154 (fun)
# Iterazione: 7 Thread_name = Thread-155 (fun)
# Iterazione: 7 Thread_name = Thread-156 (fun)
# Iterazione: 7 Thread_name = Thread-157 (fun)
# Iterazione: 7 Thread_name = Thread-158 (fun)
# Iterazione: 7 Thread_name = Thread-159 (fun)
# Iterazione: 7 Thread_name = Thread-160 (fun)
# Iterazione: 7 Thread_name = Thread-161 (fun)
# Iterazione: 7 Thread_name = Thread-162 (fun)
# Iterazione: 7 Thread_name = Thread-163 (fun)
# Iterazione: 8 Thread_name = Thread-164 (fun)
# Iterazione: 8 Thread_name = Thread-165 (fun)
# Iterazione: 8 Thread_name = Thread-166 (fun)
# Iterazione: 8 Thread_name = Thread-167 (fun)
# Iterazione: 8 Thread_name = Thread-168 (fun)
# Iterazione: 8 Thread_name = Thread-169 (fun)
# Iterazione: 8 Thread_name = Thread-170 (fun)
# Iterazione: 8 Thread_name = Thread-171 (fun)
# Iterazione: 8 Thread_name = Thread-172 (fun)
# Iterazione: 8 Thread_name = Thread-173 (fun)
# Iterazione: 8 Thread_name = Thread-174 (fun)
# Iterazione: 8 Thread_name = Thread-175 (fun)
# Iterazione: 8 Thread_name = Thread-176 (fun)
# Iterazione: 8 Thread_name = Thread-177 (fun)
# Iterazione: 8 Thread_name = Thread-178 (fun)
# Iterazione: 8 Thread_name = Thread-179 (fun)
# Iterazione: 8 Thread_name = Thread-180 (fun)
# Iterazione: 8 Thread_name = Thread-181 (fun)
# Iterazione: 8 Thread_name = Thread-182 (fun)
# Iterazione: 8 Thread_name = Thread-183 (fun)
# Iterazione: 9 Thread_name = Thread-184 (fun)
# Iterazione: 9 Thread_name = Thread-185 (fun)
# Iterazione: 9 Thread_name = Thread-186 (fun)
# Iterazione: 9 Thread_name = Thread-187 (fun)
# Iterazione: 9 Thread_name = Thread-188 (fun)
# Iterazione: 9 Thread_name = Thread-189 (fun)
# Iterazione: 9 Thread_name = Thread-190 (fun)
# Iterazione: 9 Thread_name = Thread-191 (fun)
# Iterazione: 9 Thread_name = Thread-192 (fun)
# Iterazione: 9 Thread_name = Thread-193 (fun)
# Iterazione: 9 Thread_name = Thread-194 (fun)
# Iterazione: 9 Thread_name = Thread-195 (fun)
# Iterazione: 9 Thread_name = Thread-196 (fun)
# Iterazione: 9 Thread_name = Thread-197 (fun)
# Iterazione: 9 Thread_name = Thread-198 (fun)
# Iterazione: 9 Thread_name = Thread-199 (fun)
# Iterazione: 9 Thread_name = Thread-200 (fun)
# Iterazione: 9 Thread_name = Thread-201 (fun)
# Iterazione: 9 Thread_name = Thread-202 (fun)
# Iterazione: 9 Thread_name = Thread-203 (fun)
# Iterazione: 10 Thread_name = Thread-204 (fun)
# Iterazione: 10 Thread_name = Thread-205 (fun)
# Iterazione: 10 Thread_name = Thread-206 (fun)
# Iterazione: 10 Thread_name = Thread-207 (fun)
# Iterazione: 10 Thread_name = Thread-208 (fun)
# Iterazione: 10 Thread_name = Thread-209 (fun)
# Iterazione: 10 Thread_name = Thread-210 (fun)
# Iterazione: 10 Thread_name = Thread-211 (fun)
# Iterazione: 10 Thread_name = Thread-212 (fun)
# Iterazione: 10 Thread_name = Thread-213 (fun)
# Iterazione: 10 Thread_name = Thread-214 (fun)
# Iterazione: 10 Thread_name = Thread-215 (fun)
# Iterazione: 10 Thread_name = Thread-216 (fun)
# Iterazione: 10 Thread_name = Thread-217 (fun)
# Iterazione: 10 Thread_name = Thread-218 (fun)
# Iterazione: 10 Thread_name = Thread-219 (fun)
# Iterazione: 10 Thread_name = Thread-220 (fun)
# Iterazione: 10 Thread_name = Thread-221 (fun)
# Iterazione: 10 Thread_name = Thread-222 (fun)
# Iterazione: 10 Thread_name = Thread-223 (fun)
# Iterazione: 11 Thread_name = Thread-224 (fun)
# Iterazione: 11 Thread_name = Thread-225 (fun)
# Iterazione: 11 Thread_name = Thread-226 (fun)
# Iterazione: 11 Thread_name = Thread-227 (fun)
# Iterazione: 11 Thread_name = Thread-228 (fun)
# Iterazione: 11 Thread_name = Thread-229 (fun)
# Iterazione: 11 Thread_name = Thread-230 (fun)
# Iterazione: 11 Thread_name = Thread-231 (fun)
# Iterazione: 11 Thread_name = Thread-232 (fun)
# Iterazione: 11 Thread_name = Thread-233 (fun)
# Iterazione: 11 Thread_name = Thread-234 (fun)
# Iterazione: 11 Thread_name = Thread-235 (fun)
# Iterazione: 11 Thread_name = Thread-236 (fun)
# Iterazione: 11 Thread_name = Thread-237 (fun)
# Iterazione: 11 Thread_name = Thread-238 (fun)
# Iterazione: 11 Thread_name = Thread-239 (fun)
# Iterazione: 11 Thread_name = Thread-240 (fun)
# Iterazione: 11 Thread_name = Thread-241 (fun)
# Iterazione: 11 Thread_name = Thread-242 (fun)
# Iterazione: 11 Thread_name = Thread-243 (fun)
# Iterazione: 12 Thread_name = Thread-244 (fun)
# Iterazione: 12 Thread_name = Thread-245 (fun)
# Iterazione: 12 Thread_name = Thread-246 (fun)
# Iterazione: 12 Thread_name = Thread-247 (fun)
# Iterazione: 12 Thread_name = Thread-248 (fun)
# Iterazione: 12 Thread_name = Thread-249 (fun)
# Iterazione: 12 Thread_name = Thread-250 (fun)
# Iterazione: 12 Thread_name = Thread-251 (fun)
# Iterazione: 12 Thread_name = Thread-252 (fun)
# Iterazione: 12 Thread_name = Thread-253 (fun)
# Iterazione: 12 Thread_name = Thread-254 (fun)
# Iterazione: 12 Thread_name = Thread-255 (fun)
# Iterazione: 12 Thread_name = Thread-256 (fun)
# Iterazione: 12 Thread_name = Thread-257 (fun)
# Iterazione: 12 Thread_name = Thread-258 (fun)
# Iterazione: 12 Thread_name = Thread-259 (fun)
# Iterazione: 12 Thread_name = Thread-260 (fun)
# Iterazione: 12 Thread_name = Thread-261 (fun)
# Iterazione: 12 Thread_name = Thread-262 (fun)
# Iterazione: 12 Thread_name = Thread-263 (fun)
# Iterazione: 13 Thread_name = Thread-264 (fun)
# Iterazione: 13 Thread_name = Thread-265 (fun)
# Iterazione: 13 Thread_name = Thread-266 (fun)
# Iterazione: 13 Thread_name = Thread-267 (fun)
# Iterazione: 13 Thread_name = Thread-268 (fun)
# Iterazione: 13 Thread_name = Thread-269 (fun)
# Iterazione: 13 Thread_name = Thread-270 (fun)
# Iterazione: 13 Thread_name = Thread-271 (fun)
# Iterazione: 13 Thread_name = Thread-272 (fun)
# Iterazione: 13 Thread_name = Thread-273 (fun)
# Iterazione: 13 Thread_name = Thread-274 (fun)
# Iterazione: 13 Thread_name = Thread-275 (fun)
# Iterazione: 13 Thread_name = Thread-276 (fun)
# Iterazione: 13 Thread_name = Thread-277 (fun)
# Iterazione: 13 Thread_name = Thread-278 (fun)
# Iterazione: 13 Thread_name = Thread-279 (fun)
# Iterazione: 13 Thread_name = Thread-280 (fun)
# Iterazione: 13 Thread_name = Thread-281 (fun)
# Iterazione: 13 Thread_name = Thread-282 (fun)
# Iterazione: 13 Thread_name = Thread-283 (fun)
# Iterazione: 14 Thread_name = Thread-284 (fun)
# Iterazione: 14 Thread_name = Thread-285 (fun)
# Iterazione: 14 Thread_name = Thread-286 (fun)
# Iterazione: 14 Thread_name = Thread-287 (fun)
# Iterazione: 14 Thread_name = Thread-288 (fun)
# Iterazione: 14 Thread_name = Thread-289 (fun)
# Iterazione: 14 Thread_name = Thread-290 (fun)
# Iterazione: 14 Thread_name = Thread-291 (fun)
# Iterazione: 14 Thread_name = Thread-292 (fun)
# Iterazione: 14 Thread_name = Thread-293 (fun)
# Iterazione: 14 Thread_name = Thread-294 (fun)
# Iterazione: 14 Thread_name = Thread-295 (fun)
# Iterazione: 14 Thread_name = Thread-296 (fun)
# Iterazione: 14 Thread_name = Thread-297 (fun)
# Iterazione: 14 Thread_name = Thread-298 (fun)
# Iterazione: 14 Thread_name = Thread-299 (fun)
# Iterazione: 14 Thread_name = Thread-300 (fun)
# Iterazione: 14 Thread_name = Thread-301 (fun)
# Iterazione: 14 Thread_name = Thread-302 (fun)
# Iterazione: 14 Thread_name = Thread-303 (fun)
# Iterazione: 15 Thread_name = Thread-304 (fun)
# Iterazione: 15 Thread_name = Thread-305 (fun)
# Iterazione: 15 Thread_name = Thread-306 (fun)
# Iterazione: 15 Thread_name = Thread-307 (fun)
# Iterazione: 15 Thread_name = Thread-308 (fun)
# Iterazione: 15 Thread_name = Thread-309 (fun)
# Iterazione: 15 Thread_name = Thread-310 (fun)
# Iterazione: 15 Thread_name = Thread-311 (fun)
# Iterazione: 15 Thread_name = Thread-312 (fun)
# Iterazione: 15 Thread_name = Thread-313 (fun)
# Iterazione: 15 Thread_name = Thread-314 (fun)
# Iterazione: 15 Thread_name = Thread-315 (fun)
# Iterazione: 15 Thread_name = Thread-316 (fun)
# Iterazione: 15 Thread_name = Thread-317 (fun)
# Iterazione: 15 Thread_name = Thread-318 (fun)
# Iterazione: 15 Thread_name = Thread-319 (fun)
# Iterazione: 15 Thread_name = Thread-320 (fun)
# Iterazione: 15 Thread_name = Thread-321 (fun)
# Iterazione: 15 Thread_name = Thread-322 (fun)
# Iterazione: 15 Thread_name = Thread-323 (fun)
# Iterazione: 16 Thread_name = Thread-324 (fun)
# Iterazione: 16 Thread_name = Thread-325 (fun)
# Iterazione: 16 Thread_name = Thread-326 (fun)
# Iterazione: 16 Thread_name = Thread-327 (fun)
# Iterazione: 16 Thread_name = Thread-328 (fun)
# Iterazione: 16 Thread_name = Thread-329 (fun)
# Iterazione: 16 Thread_name = Thread-330 (fun)
# Iterazione: 16 Thread_name = Thread-331 (fun)
# Iterazione: 16 Thread_name = Thread-332 (fun)
# Iterazione: 16 Thread_name = Thread-333 (fun)
# Iterazione: 16 Thread_name = Thread-334 (fun)
# Iterazione: 16 Thread_name = Thread-335 (fun)
# Iterazione: 16 Thread_name = Thread-336 (fun)
# Iterazione: 16 Thread_name = Thread-337 (fun)
# Iterazione: 16 Thread_name = Thread-338 (fun)
# Iterazione: 16 Thread_name = Thread-339 (fun)
# Iterazione: 16 Thread_name = Thread-340 (fun)
# Iterazione: 16 Thread_name = Thread-341 (fun)
# Iterazione: 16 Thread_name = Thread-342 (fun)
# Iterazione: 16 Thread_name = Thread-343 (fun)
# Iterazione: 17 Thread_name = Thread-344 (fun)
# Iterazione: 17 Thread_name = Thread-345 (fun)
# Iterazione: 17 Thread_name = Thread-346 (fun)
# Iterazione: 17 Thread_name = Thread-347 (fun)
# Iterazione: 17 Thread_name = Thread-348 (fun)
# Iterazione: 17 Thread_name = Thread-349 (fun)
# Iterazione: 17 Thread_name = Thread-350 (fun)
# Iterazione: 17 Thread_name = Thread-351 (fun)
# Iterazione: 17 Thread_name = Thread-352 (fun)
# Iterazione: 17 Thread_name = Thread-353 (fun)
# Iterazione: 17 Thread_name = Thread-354 (fun)
# Iterazione: 17 Thread_name = Thread-355 (fun)
# Iterazione: 17 Thread_name = Thread-356 (fun)
# Iterazione: 17 Thread_name = Thread-357 (fun)
# Iterazione: 17 Thread_name = Thread-358 (fun)
# Iterazione: 17 Thread_name = Thread-359 (fun)
# Iterazione: 17 Thread_name = Thread-360 (fun)
# Iterazione: 17 Thread_name = Thread-361 (fun)
# Iterazione: 17 Thread_name = Thread-362 (fun)
# Iterazione: 17 Thread_name = Thread-363 (fun)
# Iterazione: 18 Thread_name = Thread-364 (fun)
# Iterazione: 18 Thread_name = Thread-365 (fun)
# Iterazione: 18 Thread_name = Thread-366 (fun)
# Iterazione: 18 Thread_name = Thread-367 (fun)
# Iterazione: 18 Thread_name = Thread-368 (fun)
# Iterazione: 18 Thread_name = Thread-369 (fun)
# Iterazione: 18 Thread_name = Thread-370 (fun)
# Iterazione: 18 Thread_name = Thread-371 (fun)
# Iterazione: 18 Thread_name = Thread-372 (fun)
# Iterazione: 18 Thread_name = Thread-373 (fun)
# Iterazione: 18 Thread_name = Thread-374 (fun)
# Iterazione: 18 Thread_name = Thread-375 (fun)
# Iterazione: 18 Thread_name = Thread-376 (fun)
# Iterazione: 18 Thread_name = Thread-377 (fun)
# Iterazione: 18 Thread_name = Thread-378 (fun)
# Iterazione: 18 Thread_name = Thread-379 (fun)
# Iterazione: 18 Thread_name = Thread-380 (fun)
# Iterazione: 18 Thread_name = Thread-381 (fun)
# Iterazione: 18 Thread_name = Thread-382 (fun)
# Iterazione: 18 Thread_name = Thread-383 (fun)
# Iterazione: 19 Thread_name = Thread-384 (fun)
# Iterazione: 19 Thread_name = Thread-385 (fun)
# Iterazione: 19 Thread_name = Thread-386 (fun)
# Iterazione: 19 Thread_name = Thread-387 (fun)
# Iterazione: 19 Thread_name = Thread-388 (fun)
# Iterazione: 19 Thread_name = Thread-389 (fun)
# Iterazione: 19 Thread_name = Thread-390 (fun)
# Iterazione: 19 Thread_name = Thread-391 (fun)
# Iterazione: 19 Thread_name = Thread-392 (fun)
# Iterazione: 19 Thread_name = Thread-393 (fun)
# Iterazione: 19 Thread_name = Thread-394 (fun)
# Iterazione: 19 Thread_name = Thread-395 (fun)
# Iterazione: 19 Thread_name = Thread-396 (fun)
# Iterazione: 19 Thread_name = Thread-397 (fun)
# Iterazione: 19 Thread_name = Thread-398 (fun)
# Iterazione: 19 Thread_name = Thread-399 (fun)
# Iterazione: 19 Thread_name = Thread-400 (fun)
# Iterazione: 19 Thread_name = Thread-401 (fun)
# Iterazione: 19 Thread_name = Thread-402 (fun)
# Iterazione: 19 Thread_name = Thread-403 (fun)
# Iterazione: 20 Thread_name = Thread-404 (fun)
# Iterazione: 20 Thread_name = Thread-405 (fun)
# Iterazione: 20 Thread_name = Thread-406 (fun)
# Iterazione: 20 Thread_name = Thread-407 (fun)
# Iterazione: 20 Thread_name = Thread-408 (fun)
# Iterazione: 20 Thread_name = Thread-409 (fun)
# Iterazione: 20 Thread_name = Thread-410 (fun)
# Iterazione: 20 Thread_name = Thread-411 (fun)
# Iterazione: 20 Thread_name = Thread-412 (fun)
# Iterazione: 20 Thread_name = Thread-413 (fun)
# Iterazione: 20 Thread_name = Thread-414 (fun)
# Iterazione: 20 Thread_name = Thread-415 (fun)
# Iterazione: 20 Thread_name = Thread-416 (fun)
# Iterazione: 20 Thread_name = Thread-417 (fun)
# Iterazione: 20 Thread_name = Thread-418 (fun)
# Iterazione: 20 Thread_name = Thread-419 (fun)
# Iterazione: 20 Thread_name = Thread-420 (fun)
# Iterazione: 20 Thread_name = Thread-421 (fun)
# Iterazione: 20 Thread_name = Thread-422 (fun)
# Iterazione: 20 Thread_name = Thread-423 (fun)
# Iterazione: 21 Thread_name = Thread-424 (fun)
# Iterazione: 21 Thread_name = Thread-425 (fun)
# Iterazione: 21 Thread_name = Thread-426 (fun)
# Iterazione: 21 Thread_name = Thread-427 (fun)
# Iterazione: 21 Thread_name = Thread-428 (fun)
# Iterazione: 21 Thread_name = Thread-429 (fun)
# Iterazione: 21 Thread_name = Thread-430 (fun)
# Iterazione: 21 Thread_name = Thread-431 (fun)
# Iterazione: 21 Thread_name = Thread-432 (fun)
# Iterazione: 21 Thread_name = Thread-433 (fun)
# Iterazione: 21 Thread_name = Thread-434 (fun)
# Iterazione: 21 Thread_name = Thread-435 (fun)
# Iterazione: 21 Thread_name = Thread-436 (fun)
# Iterazione: 21 Thread_name = Thread-437 (fun)
# Iterazione: 21 Thread_name = Thread-438 (fun)
# Iterazione: 21 Thread_name = Thread-439 (fun)
# Iterazione: 21 Thread_name = Thread-440 (fun)
# Iterazione: 21 Thread_name = Thread-441 (fun)
# Iterazione: 21 Thread_name = Thread-442 (fun)
# Iterazione: 21 Thread_name = Thread-443 (fun)
# Iterazione: 22 Thread_name = Thread-444 (fun)
# Iterazione: 22 Thread_name = Thread-445 (fun)
# Iterazione: 22 Thread_name = Thread-446 (fun)
# Iterazione: 22 Thread_name = Thread-447 (fun)
# Iterazione: 22 Thread_name = Thread-448 (fun)
# Iterazione: 22 Thread_name = Thread-449 (fun)
# Iterazione: 22 Thread_name = Thread-450 (fun)
# Iterazione: 22 Thread_name = Thread-451 (fun)
# Iterazione: 22 Thread_name = Thread-452 (fun)
# Iterazione: 22 Thread_name = Thread-453 (fun)
# Iterazione: 22 Thread_name = Thread-454 (fun)
# Iterazione: 22 Thread_name = Thread-455 (fun)
# Iterazione: 22 Thread_name = Thread-456 (fun)
# Iterazione: 22 Thread_name = Thread-457 (fun)
# Iterazione: 22 Thread_name = Thread-458 (fun)
# Iterazione: 22 Thread_name = Thread-459 (fun)
# Iterazione: 22 Thread_name = Thread-460 (fun)
# Iterazione: 22 Thread_name = Thread-461 (fun)
# Iterazione: 22 Thread_name = Thread-462 (fun)
# Iterazione: 22 Thread_name = Thread-463 (fun)
# Iterazione: 23 Thread_name = Thread-464 (fun)
# Iterazione: 23 Thread_name = Thread-465 (fun)
# Iterazione: 23 Thread_name = Thread-466 (fun)
# Iterazione: 23 Thread_name = Thread-467 (fun)
# Iterazione: 23 Thread_name = Thread-468 (fun)
# Iterazione: 23 Thread_name = Thread-469 (fun)
# Iterazione: 23 Thread_name = Thread-470 (fun)
# Iterazione: 23 Thread_name = Thread-471 (fun)
# Iterazione: 23 Thread_name = Thread-472 (fun)
# Iterazione: 23 Thread_name = Thread-473 (fun)
# Iterazione: 23 Thread_name = Thread-474 (fun)
# Iterazione: 23 Thread_name = Thread-475 (fun)
# Iterazione: 23 Thread_name = Thread-476 (fun)
# Iterazione: 23 Thread_name = Thread-477 (fun)
# Iterazione: 23 Thread_name = Thread-478 (fun)
# Iterazione: 23 Thread_name = Thread-479 (fun)
# Iterazione: 23 Thread_name = Thread-480 (fun)
# Iterazione: 23 Thread_name = Thread-481 (fun)
# Iterazione: 23 Thread_name = Thread-482 (fun)
# Iterazione: 23 Thread_name = Thread-483 (fun)
# Iterazione: 24 Thread_name = Thread-484 (fun)
# Iterazione: 24 Thread_name = Thread-485 (fun)
# Iterazione: 24 Thread_name = Thread-486 (fun)
# Iterazione: 24 Thread_name = Thread-487 (fun)
# Iterazione: 24 Thread_name = Thread-488 (fun)
# Iterazione: 24 Thread_name = Thread-489 (fun)
# Iterazione: 24 Thread_name = Thread-490 (fun)
# Iterazione: 24 Thread_name = Thread-491 (fun)
# Iterazione: 24 Thread_name = Thread-492 (fun)
# Iterazione: 24 Thread_name = Thread-493 (fun)
# Iterazione: 24 Thread_name = Thread-494 (fun)
# Iterazione: 24 Thread_name = Thread-495 (fun)
# Iterazione: 24 Thread_name = Thread-496 (fun)
# Iterazione: 24 Thread_name = Thread-497 (fun)
# Iterazione: 24 Thread_name = Thread-498 (fun)
# Iterazione: 24 Thread_name = Thread-499 (fun)
# Iterazione: 24 Thread_name = Thread-500 (fun)
# Iterazione: 24 Thread_name = Thread-501 (fun)
# Iterazione: 24 Thread_name = Thread-502 (fun)
# Iterazione: 24 Thread_name = Thread-503 (fun)
# Iterazione: 25 Thread_name = Thread-504 (fun)
# Iterazione: 25 Thread_name = Thread-505 (fun)
# Iterazione: 25 Thread_name = Thread-506 (fun)
# Iterazione: 25 Thread_name = Thread-507 (fun)
# Iterazione: 25 Thread_name = Thread-508 (fun)
# Iterazione: 25 Thread_name = Thread-509 (fun)
# Iterazione: 25 Thread_name = Thread-510 (fun)
# Iterazione: 25 Thread_name = Thread-511 (fun)
# Iterazione: 25 Thread_name = Thread-512 (fun)
# Iterazione: 25 Thread_name = Thread-513 (fun)
# Iterazione: 25 Thread_name = Thread-514 (fun)
# Iterazione: 25 Thread_name = Thread-515 (fun)
# Iterazione: 25 Thread_name = Thread-516 (fun)
# Iterazione: 25 Thread_name = Thread-517 (fun)
# Iterazione: 25 Thread_name = Thread-518 (fun)
# Iterazione: 25 Thread_name = Thread-519 (fun)
# Iterazione: 25 Thread_name = Thread-520 (fun)
# Iterazione: 25 Thread_name = Thread-521 (fun)
# Iterazione: 25 Thread_name = Thread-522 (fun)
# Iterazione: 25 Thread_name = Thread-523 (fun)
# Iterazione: 26 Thread_name = Thread-524 (fun)
# Iterazione: 26 Thread_name = Thread-525 (fun)
# Iterazione: 26 Thread_name = Thread-526 (fun)
# Iterazione: 26 Thread_name = Thread-527 (fun)
# Iterazione: 26 Thread_name = Thread-528 (fun)
# Iterazione: 26 Thread_name = Thread-529 (fun)
# Iterazione: 26 Thread_name = Thread-530 (fun)
# Iterazione: 26 Thread_name = Thread-531 (fun)
# Iterazione: 26 Thread_name = Thread-532 (fun)
# Iterazione: 26 Thread_name = Thread-533 (fun)
# Iterazione: 26 Thread_name = Thread-534 (fun)
# Iterazione: 26 Thread_name = Thread-535 (fun)
# Iterazione: 26 Thread_name = Thread-536 (fun)
# Iterazione: 26 Thread_name = Thread-537 (fun)
# Iterazione: 26 Thread_name = Thread-538 (fun)
# Iterazione: 26 Thread_name = Thread-539 (fun)
# Iterazione: 26 Thread_name = Thread-540 (fun)
# Iterazione: 26 Thread_name = Thread-541 (fun)
# Iterazione: 26 Thread_name = Thread-542 (fun)
# Iterazione: 26 Thread_name = Thread-543 (fun)
# Iterazione: 27 Thread_name = Thread-544 (fun)
# Iterazione: 27 Thread_name = Thread-545 (fun)
# Iterazione: 27 Thread_name = Thread-546 (fun)
# Iterazione: 27 Thread_name = Thread-547 (fun)
# Iterazione: 27 Thread_name = Thread-548 (fun)
# Iterazione: 27 Thread_name = Thread-549 (fun)
# Iterazione: 27 Thread_name = Thread-550 (fun)
# Iterazione: 27 Thread_name = Thread-551 (fun)
# Iterazione: 27 Thread_name = Thread-552 (fun)
# Iterazione: 27 Thread_name = Thread-553 (fun)
# Iterazione: 27 Thread_name = Thread-554 (fun)
# Iterazione: 27 Thread_name = Thread-555 (fun)
# Iterazione: 27 Thread_name = Thread-556 (fun)
# Iterazione: 27 Thread_name = Thread-557 (fun)
# Iterazione: 27 Thread_name = Thread-558 (fun)
# Iterazione: 27 Thread_name = Thread-559 (fun)
# Iterazione: 27 Thread_name = Thread-560 (fun)
# Iterazione: 27 Thread_name = Thread-561 (fun)
# Iterazione: 27 Thread_name = Thread-562 (fun)
# Iterazione: 27 Thread_name = Thread-563 (fun)
# Iterazione: 28 Thread_name = Thread-564 (fun)
# Iterazione: 28 Thread_name = Thread-565 (fun)
# Iterazione: 28 Thread_name = Thread-566 (fun)
# Iterazione: 28 Thread_name = Thread-567 (fun)
# Iterazione: 28 Thread_name = Thread-568 (fun)
# Iterazione: 28 Thread_name = Thread-569 (fun)
# Iterazione: 28 Thread_name = Thread-570 (fun)
# Iterazione: 28 Thread_name = Thread-571 (fun)
# Iterazione: 28 Thread_name = Thread-572 (fun)
# Iterazione: 28 Thread_name = Thread-573 (fun)
# Iterazione: 28 Thread_name = Thread-574 (fun)
# Iterazione: 28 Thread_name = Thread-575 (fun)
# Iterazione: 28 Thread_name = Thread-576 (fun)
# Iterazione: 28 Thread_name = Thread-577 (fun)
# Iterazione: 28 Thread_name = Thread-578 (fun)
# Iterazione: 28 Thread_name = Thread-579 (fun)
# Iterazione: 28 Thread_name = Thread-580 (fun)
# Iterazione: 28 Thread_name = Thread-581 (fun)
# Iterazione: 28 Thread_name = Thread-582 (fun)
# Iterazione: 28 Thread_name = Thread-583 (fun)
# Iterazione: 29 Thread_name = Thread-584 (fun)
# Iterazione: 29 Thread_name = Thread-585 (fun)
# Iterazione: 29 Thread_name = Thread-586 (fun)
# Iterazione: 29 Thread_name = Thread-587 (fun)
# Iterazione: 29 Thread_name = Thread-588 (fun)
# Iterazione: 29 Thread_name = Thread-589 (fun)
# Iterazione: 29 Thread_name = Thread-590 (fun)
# Iterazione: 29 Thread_name = Thread-591 (fun)
# Iterazione: 29 Thread_name = Thread-592 (fun)
# Iterazione: 29 Thread_name = Thread-593 (fun)
# Iterazione: 29 Thread_name = Thread-594 (fun)
# Iterazione: 29 Thread_name = Thread-595 (fun)
# Iterazione: 29 Thread_name = Thread-596 (fun)
# Iterazione: 29 Thread_name = Thread-597 (fun)
# Iterazione: 29 Thread_name = Thread-598 (fun)
# Iterazione: 29 Thread_name = Thread-599 (fun)
# Iterazione: 29 Thread_name = Thread-600 (fun)
# Iterazione: 29 Thread_name = Thread-601 (fun)
# Iterazione: 29 Thread_name = Thread-602 (fun)
# Iterazione: 29 Thread_name = Thread-603 (fun)
# Iterazione: 30 Thread_name = Thread-604 (fun)
# Iterazione: 30 Thread_name = Thread-605 (fun)
# Iterazione: 30 Thread_name = Thread-606 (fun)
# Iterazione: 30 Thread_name = Thread-607 (fun)
# Iterazione: 30 Thread_name = Thread-608 (fun)
# Iterazione: 30 Thread_name = Thread-609 (fun)
# Iterazione: 30 Thread_name = Thread-610 (fun)
# Iterazione: 30 Thread_name = Thread-611 (fun)
# Iterazione: 30 Thread_name = Thread-612 (fun)
# Iterazione: 30 Thread_name = Thread-613 (fun)
# Iterazione: 30 Thread_name = Thread-614 (fun)
# Iterazione: 30 Thread_name = Thread-615 (fun)
# Iterazione: 30 Thread_name = Thread-616 (fun)
# Iterazione: 30 Thread_name = Thread-617 (fun)
# Iterazione: 30 Thread_name = Thread-618 (fun)
# Iterazione: 30 Thread_name = Thread-619 (fun)
# Iterazione: 30 Thread_name = Thread-620 (fun)
# Iterazione: 30 Thread_name = Thread-621 (fun)
# Iterazione: 30 Thread_name = Thread-622 (fun)
# Iterazione: 30 Thread_name = Thread-623 (fun)
# Iterazione: 31 Thread_name = Thread-624 (fun)
# Iterazione: 31 Thread_name = Thread-625 (fun)
# Iterazione: 31 Thread_name = Thread-626 (fun)
# Iterazione: 31 Thread_name = Thread-627 (fun)
# Iterazione: 31 Thread_name = Thread-628 (fun)
# Iterazione: 31 Thread_name = Thread-629 (fun)
# Iterazione: 31 Thread_name = Thread-630 (fun)
# Iterazione: 31 Thread_name = Thread-631 (fun)
# Iterazione: 31 Thread_name = Thread-632 (fun)
# Iterazione: 31 Thread_name = Thread-633 (fun)
# Iterazione: 31 Thread_name = Thread-634 (fun)
# Iterazione: 31 Thread_name = Thread-635 (fun)
# Iterazione: 31 Thread_name = Thread-636 (fun)
# Iterazione: 31 Thread_name = Thread-637 (fun)
# Iterazione: 31 Thread_name = Thread-638 (fun)
# Iterazione: 31 Thread_name = Thread-639 (fun)
# Iterazione: 31 Thread_name = Thread-640 (fun)
# Iterazione: 31 Thread_name = Thread-641 (fun)
# Iterazione: 31 Thread_name = Thread-642 (fun)
# Iterazione: 31 Thread_name = Thread-643 (fun)
# Iterazione: 32 Thread_name = Thread-644 (fun)
# Iterazione: 32 Thread_name = Thread-645 (fun)
# Iterazione: 32 Thread_name = Thread-646 (fun)
# Iterazione: 32 Thread_name = Thread-647 (fun)
# Iterazione: 32 Thread_name = Thread-648 (fun)
# Iterazione: 32 Thread_name = Thread-649 (fun)
# Iterazione: 32 Thread_name = Thread-650 (fun)
# Iterazione: 32 Thread_name = Thread-651 (fun)
# Iterazione: 32 Thread_name = Thread-652 (fun)
# Iterazione: 32 Thread_name = Thread-653 (fun)
# Iterazione: 32 Thread_name = Thread-654 (fun)
# Iterazione: 32 Thread_name = Thread-655 (fun)
# Iterazione: 32 Thread_name = Thread-656 (fun)
# Iterazione: 32 Thread_name = Thread-657 (fun)
# Iterazione: 32 Thread_name = Thread-658 (fun)
# Iterazione: 32 Thread_name = Thread-659 (fun)
# Iterazione: 32 Thread_name = Thread-660 (fun)
# Iterazione: 32 Thread_name = Thread-661 (fun)
# Iterazione: 32 Thread_name = Thread-662 (fun)
# Iterazione: 32 Thread_name = Thread-663 (fun)
# Iterazione: 33 Thread_name = Thread-664 (fun)
# Iterazione: 33 Thread_name = Thread-665 (fun)
# Iterazione: 33 Thread_name = Thread-666 (fun)
# Iterazione: 33 Thread_name = Thread-667 (fun)
# Iterazione: 33 Thread_name = Thread-668 (fun)
# Iterazione: 33 Thread_name = Thread-669 (fun)
# Iterazione: 33 Thread_name = Thread-670 (fun)
# Iterazione: 33 Thread_name = Thread-671 (fun)
# Iterazione: 33 Thread_name = Thread-672 (fun)
# Iterazione: 33 Thread_name = Thread-673 (fun)
# Iterazione: 33 Thread_name = Thread-674 (fun)
# Iterazione: 33 Thread_name = Thread-675 (fun)
# Iterazione: 33 Thread_name = Thread-676 (fun)
# Iterazione: 33 Thread_name = Thread-677 (fun)
# Iterazione: 33 Thread_name = Thread-678 (fun)
# Iterazione: 33 Thread_name = Thread-679 (fun)
# Iterazione: 33 Thread_name = Thread-680 (fun)
# Iterazione: 33 Thread_name = Thread-681 (fun)
# Iterazione: 33 Thread_name = Thread-682 (fun)
# Iterazione: 33 Thread_name = Thread-683 (fun)
# Iterazione: 34 Thread_name = Thread-684 (fun)
# Iterazione: 34 Thread_name = Thread-685 (fun)
# Iterazione: 34 Thread_name = Thread-686 (fun)
# Iterazione: 34 Thread_name = Thread-687 (fun)
# Iterazione: 34 Thread_name = Thread-688 (fun)
# Iterazione: 34 Thread_name = Thread-689 (fun)
# Iterazione: 34 Thread_name = Thread-690 (fun)
# Iterazione: 34 Thread_name = Thread-691 (fun)
# Iterazione: 34 Thread_name = Thread-692 (fun)
# Iterazione: 34 Thread_name = Thread-693 (fun)
# Iterazione: 34 Thread_name = Thread-694 (fun)
# Iterazione: 34 Thread_name = Thread-695 (fun)
# Iterazione: 34 Thread_name = Thread-696 (fun)
# Iterazione: 34 Thread_name = Thread-697 (fun)
# Iterazione: 34 Thread_name = Thread-698 (fun)
# Iterazione: 34 Thread_name = Thread-699 (fun)
# Iterazione: 34 Thread_name = Thread-700 (fun)
# Iterazione: 34 Thread_name = Thread-701 (fun)
# Iterazione: 34 Thread_name = Thread-702 (fun)
# Iterazione: 34 Thread_name = Thread-703 (fun)
# Iterazione: 35 Thread_name = Thread-704 (fun)
# Iterazione: 35 Thread_name = Thread-705 (fun)
# Iterazione: 35 Thread_name = Thread-706 (fun)
# Iterazione: 35 Thread_name = Thread-707 (fun)
# Iterazione: 35 Thread_name = Thread-708 (fun)
# Iterazione: 35 Thread_name = Thread-709 (fun)
# Iterazione: 35 Thread_name = Thread-710 (fun)
# Iterazione: 35 Thread_name = Thread-711 (fun)
# Iterazione: 35 Thread_name = Thread-712 (fun)
# Iterazione: 35 Thread_name = Thread-713 (fun)
# Iterazione: 35 Thread_name = Thread-714 (fun)
# Iterazione: 35 Thread_name = Thread-715 (fun)
# Iterazione: 35 Thread_name = Thread-716 (fun)
# Iterazione: 35 Thread_name = Thread-717 (fun)
# Iterazione: 35 Thread_name = Thread-718 (fun)
# Iterazione: 35 Thread_name = Thread-719 (fun)
# Iterazione: 35 Thread_name = Thread-720 (fun)
# Iterazione: 35 Thread_name = Thread-721 (fun)
# Iterazione: 35 Thread_name = Thread-722 (fun)
# Iterazione: 35 Thread_name = Thread-723 (fun)
# Iterazione: 36 Thread_name = Thread-724 (fun)
# Iterazione: 36 Thread_name = Thread-725 (fun)
# Iterazione: 36 Thread_name = Thread-726 (fun)
# Iterazione: 36 Thread_name = Thread-727 (fun)
# Iterazione: 36 Thread_name = Thread-728 (fun)
# Iterazione: 36 Thread_name = Thread-729 (fun)
# Iterazione: 36 Thread_name = Thread-730 (fun)
# Iterazione: 36 Thread_name = Thread-731 (fun)
# Iterazione: 36 Thread_name = Thread-732 (fun)
# Iterazione: 36 Thread_name = Thread-733 (fun)
# Iterazione: 36 Thread_name = Thread-734 (fun)
# Iterazione: 36 Thread_name = Thread-735 (fun)
# Iterazione: 36 Thread_name = Thread-736 (fun)
# Iterazione: 36 Thread_name = Thread-737 (fun)
# Iterazione: 36 Thread_name = Thread-738 (fun)
# Iterazione: 36 Thread_name = Thread-739 (fun)
# Iterazione: 36 Thread_name = Thread-740 (fun)
# Iterazione: 36 Thread_name = Thread-741 (fun)
# Iterazione: 36 Thread_name = Thread-742 (fun)
# Iterazione: 36 Thread_name = Thread-743 (fun)
# Iterazione: 37 Thread_name = Thread-744 (fun)
# Iterazione: 37 Thread_name = Thread-745 (fun)
# Iterazione: 37 Thread_name = Thread-746 (fun)
# Iterazione: 37 Thread_name = Thread-747 (fun)
# Iterazione: 37 Thread_name = Thread-748 (fun)
# Iterazione: 37 Thread_name = Thread-749 (fun)
# Iterazione: 37 Thread_name = Thread-750 (fun)
# Iterazione: 37 Thread_name = Thread-751 (fun)
# Iterazione: 37 Thread_name = Thread-752 (fun)
# Iterazione: 37 Thread_name = Thread-753 (fun)
# Iterazione: 37 Thread_name = Thread-754 (fun)
# Iterazione: 37 Thread_name = Thread-755 (fun)
# Iterazione: 37 Thread_name = Thread-756 (fun)
# Iterazione: 37 Thread_name = Thread-757 (fun)
# Iterazione: 37 Thread_name = Thread-758 (fun)
# Iterazione: 37 Thread_name = Thread-759 (fun)
# Iterazione: 37 Thread_name = Thread-760 (fun)
# Iterazione: 37 Thread_name = Thread-761 (fun)
# Iterazione: 37 Thread_name = Thread-762 (fun)
# Iterazione: 37 Thread_name = Thread-763 (fun)
# Iterazione: 38 Thread_name = Thread-764 (fun)
# Iterazione: 38 Thread_name = Thread-765 (fun)
# Iterazione: 38 Thread_name = Thread-766 (fun)
# Iterazione: 38 Thread_name = Thread-767 (fun)
# Iterazione: 38 Thread_name = Thread-768 (fun)
# Iterazione: 38 Thread_name = Thread-769 (fun)
# Iterazione: 38 Thread_name = Thread-770 (fun)
# Iterazione: 38 Thread_name = Thread-771 (fun)
# Iterazione: 38 Thread_name = Thread-772 (fun)
# Iterazione: 38 Thread_name = Thread-773 (fun)
# Iterazione: 38 Thread_name = Thread-774 (fun)
# Iterazione: 38 Thread_name = Thread-775 (fun)
# Iterazione: 38 Thread_name = Thread-776 (fun)
# Iterazione: 38 Thread_name = Thread-777 (fun)
# Iterazione: 38 Thread_name = Thread-778 (fun)
# Iterazione: 38 Thread_name = Thread-779 (fun)
# Iterazione: 38 Thread_name = Thread-780 (fun)
# Iterazione: 38 Thread_name = Thread-781 (fun)
# Iterazione: 38 Thread_name = Thread-782 (fun)
# Iterazione: 38 Thread_name = Thread-783 (fun)
# Iterazione: 39 Thread_name = Thread-784 (fun)
# Iterazione: 39 Thread_name = Thread-785 (fun)
# Iterazione: 39 Thread_name = Thread-786 (fun)
# Iterazione: 39 Thread_name = Thread-787 (fun)
# Iterazione: 39 Thread_name = Thread-788 (fun)
# Iterazione: 39 Thread_name = Thread-789 (fun)
# Iterazione: 39 Thread_name = Thread-790 (fun)
# Iterazione: 39 Thread_name = Thread-791 (fun)
# Iterazione: 39 Thread_name = Thread-792 (fun)
# Iterazione: 39 Thread_name = Thread-793 (fun)
# Iterazione: 39 Thread_name = Thread-794 (fun)
# Iterazione: 39 Thread_name = Thread-795 (fun)
# Iterazione: 39 Thread_name = Thread-796 (fun)
# Iterazione: 39 Thread_name = Thread-797 (fun)
# Iterazione: 39 Thread_name = Thread-798 (fun)
# Iterazione: 39 Thread_name = Thread-799 (fun)
# Iterazione: 39 Thread_name = Thread-800 (fun)
# Iterazione: 39 Thread_name = Thread-801 (fun)
# Iterazione: 39 Thread_name = Thread-802 (fun)
# Iterazione: 39 Thread_name = Thread-803 (fun)
# Iterazione: 40 Thread_name = Thread-804 (fun)
# Iterazione: 40 Thread_name = Thread-805 (fun)
# Iterazione: 40 Thread_name = Thread-806 (fun)
# Iterazione: 40 Thread_name = Thread-807 (fun)
# Iterazione: 40 Thread_name = Thread-808 (fun)
# Iterazione: 40 Thread_name = Thread-809 (fun)
# Iterazione: 40 Thread_name = Thread-810 (fun)
# Iterazione: 40 Thread_name = Thread-811 (fun)
# Iterazione: 40 Thread_name = Thread-812 (fun)
# Iterazione: 40 Thread_name = Thread-813 (fun)
# Iterazione: 40 Thread_name = Thread-814 (fun)
# Iterazione: 40 Thread_name = Thread-815 (fun)
# Iterazione: 40 Thread_name = Thread-816 (fun)
# Iterazione: 40 Thread_name = Thread-817 (fun)
# Iterazione: 40 Thread_name = Thread-818 (fun)
# Iterazione: 40 Thread_name = Thread-819 (fun)
# Iterazione: 40 Thread_name = Thread-820 (fun)
# Iterazione: 40 Thread_name = Thread-821 (fun)
# Iterazione: 40 Thread_name = Thread-822 (fun)
# Iterazione: 40 Thread_name = Thread-823 (fun)
# Iterazione: 41 Thread_name = Thread-824 (fun)
# Iterazione: 41 Thread_name = Thread-825 (fun)
# Iterazione: 41 Thread_name = Thread-826 (fun)
# Iterazione: 41 Thread_name = Thread-827 (fun)
# Iterazione: 41 Thread_name = Thread-828 (fun)
# Iterazione: 41 Thread_name = Thread-829 (fun)
# Iterazione: 41 Thread_name = Thread-830 (fun)
# Iterazione: 41 Thread_name = Thread-831 (fun)
# Iterazione: 41 Thread_name = Thread-832 (fun)
# Iterazione: 41 Thread_name = Thread-833 (fun)
# Iterazione: 41 Thread_name = Thread-834 (fun)
# Iterazione: 41 Thread_name = Thread-835 (fun)
# Iterazione: 41 Thread_name = Thread-836 (fun)
# Iterazione: 41 Thread_name = Thread-837 (fun)
# Iterazione: 41 Thread_name = Thread-838 (fun)
# Iterazione: 41 Thread_name = Thread-839 (fun)
# Iterazione: 41 Thread_name = Thread-840 (fun)
# Iterazione: 41 Thread_name = Thread-841 (fun)
# Iterazione: 41 Thread_name = Thread-842 (fun)
# Iterazione: 41 Thread_name = Thread-843 (fun)
# Iterazione: 42 Thread_name = Thread-844 (fun)
# Iterazione: 42 Thread_name = Thread-845 (fun)
# Iterazione: 42 Thread_name = Thread-846 (fun)
# Iterazione: 42 Thread_name = Thread-847 (fun)
# Iterazione: 42 Thread_name = Thread-848 (fun)
# Iterazione: 42 Thread_name = Thread-849 (fun)
# Iterazione: 42 Thread_name = Thread-850 (fun)
# Iterazione: 42 Thread_name = Thread-851 (fun)
# Iterazione: 42 Thread_name = Thread-852 (fun)
# Iterazione: 42 Thread_name = Thread-853 (fun)
# Iterazione: 42 Thread_name = Thread-854 (fun)
# Iterazione: 42 Thread_name = Thread-855 (fun)
# Iterazione: 42 Thread_name = Thread-856 (fun)
# Iterazione: 42 Thread_name = Thread-857 (fun)
# Iterazione: 42 Thread_name = Thread-858 (fun)
# Iterazione: 42 Thread_name = Thread-859 (fun)
# Iterazione: 42 Thread_name = Thread-860 (fun)
# Iterazione: 42 Thread_name = Thread-861 (fun)
# Iterazione: 42 Thread_name = Thread-862 (fun)
# Iterazione: 42 Thread_name = Thread-863 (fun)
# Iterazione: 43 Thread_name = Thread-864 (fun)
# Iterazione: 43 Thread_name = Thread-865 (fun)
# Iterazione: 43 Thread_name = Thread-866 (fun)
# Iterazione: 43 Thread_name = Thread-867 (fun)
# Iterazione: 43 Thread_name = Thread-868 (fun)
# Iterazione: 43 Thread_name = Thread-869 (fun)
# Iterazione: 43 Thread_name = Thread-870 (fun)
# Iterazione: 43 Thread_name = Thread-871 (fun)
# Iterazione: 43 Thread_name = Thread-872 (fun)
# Iterazione: 43 Thread_name = Thread-873 (fun)
# Iterazione: 43 Thread_name = Thread-874 (fun)
# Iterazione: 43 Thread_name = Thread-875 (fun)
# Iterazione: 43 Thread_name = Thread-876 (fun)
# Iterazione: 43 Thread_name = Thread-877 (fun)
# Iterazione: 43 Thread_name = Thread-878 (fun)
# Iterazione: 43 Thread_name = Thread-879 (fun)
# Iterazione: 43 Thread_name = Thread-880 (fun)
# Iterazione: 43 Thread_name = Thread-881 (fun)
# Iterazione: 43 Thread_name = Thread-882 (fun)
# Iterazione: 43 Thread_name = Thread-883 (fun)
# Iterazione: 44 Thread_name = Thread-884 (fun)
# Iterazione: 44 Thread_name = Thread-885 (fun)
# Iterazione: 44 Thread_name = Thread-886 (fun)
# Iterazione: 44 Thread_name = Thread-887 (fun)
# Iterazione: 44 Thread_name = Thread-888 (fun)
# Iterazione: 44 Thread_name = Thread-889 (fun)
# Iterazione: 44 Thread_name = Thread-890 (fun)
# Iterazione: 44 Thread_name = Thread-891 (fun)
# Iterazione: 44 Thread_name = Thread-892 (fun)
# Iterazione: 44 Thread_name = Thread-893 (fun)
# Iterazione: 44 Thread_name = Thread-894 (fun)
# Iterazione: 44 Thread_name = Thread-895 (fun)
# Iterazione: 44 Thread_name = Thread-896 (fun)
# Iterazione: 44 Thread_name = Thread-897 (fun)
# Iterazione: 44 Thread_name = Thread-898 (fun)
# Iterazione: 44 Thread_name = Thread-899 (fun)
# Iterazione: 44 Thread_name = Thread-900 (fun)
# Iterazione: 44 Thread_name = Thread-901 (fun)
# Iterazione: 44 Thread_name = Thread-902 (fun)
# Iterazione: 44 Thread_name = Thread-903 (fun)
# Iterazione: 45 Thread_name = Thread-904 (fun)
# Iterazione: 45 Thread_name = Thread-905 (fun)
# Iterazione: 45 Thread_name = Thread-906 (fun)
# Iterazione: 45 Thread_name = Thread-907 (fun)
# Iterazione: 45 Thread_name = Thread-908 (fun)
# Iterazione: 45 Thread_name = Thread-909 (fun)
# Iterazione: 45 Thread_name = Thread-910 (fun)
# Iterazione: 45 Thread_name = Thread-911 (fun)
# Iterazione: 45 Thread_name = Thread-912 (fun)
# Iterazione: 45 Thread_name = Thread-913 (fun)
# Iterazione: 45 Thread_name = Thread-914 (fun)
# Iterazione: 45 Thread_name = Thread-915 (fun)
# Iterazione: 45 Thread_name = Thread-916 (fun)
# Iterazione: 45 Thread_name = Thread-917 (fun)
# Iterazione: 45 Thread_name = Thread-918 (fun)
# Iterazione: 45 Thread_name = Thread-919 (fun)
# Iterazione: 45 Thread_name = Thread-920 (fun)
# Iterazione: 45 Thread_name = Thread-921 (fun)
# Iterazione: 45 Thread_name = Thread-922 (fun)
# Iterazione: 45 Thread_name = Thread-923 (fun)
# Iterazione: 46 Thread_name = Thread-924 (fun)
# Iterazione: 46 Thread_name = Thread-925 (fun)
# Iterazione: 46 Thread_name = Thread-926 (fun)
# Iterazione: 46 Thread_name = Thread-927 (fun)
# Iterazione: 46 Thread_name = Thread-928 (fun)
# Iterazione: 46 Thread_name = Thread-929 (fun)
# Iterazione: 46 Thread_name = Thread-930 (fun)
# Iterazione: 46 Thread_name = Thread-931 (fun)
# Iterazione: 46 Thread_name = Thread-932 (fun)
# Iterazione: 46 Thread_name = Thread-933 (fun)
# Iterazione: 46 Thread_name = Thread-934 (fun)
# Iterazione: 46 Thread_name = Thread-935 (fun)
# Iterazione: 46 Thread_name = Thread-936 (fun)
# Iterazione: 46 Thread_name = Thread-937 (fun)
# Iterazione: 46 Thread_name = Thread-938 (fun)
# Iterazione: 46 Thread_name = Thread-939 (fun)
# Iterazione: 46 Thread_name = Thread-940 (fun)
# Iterazione: 46 Thread_name = Thread-941 (fun)
# Iterazione: 46 Thread_name = Thread-942 (fun)
# Iterazione: 46 Thread_name = Thread-943 (fun)
# Iterazione: 47 Thread_name = Thread-944 (fun)
# Iterazione: 47 Thread_name = Thread-945 (fun)
# Iterazione: 47 Thread_name = Thread-946 (fun)
# Iterazione: 47 Thread_name = Thread-947 (fun)
# Iterazione: 47 Thread_name = Thread-948 (fun)
# Iterazione: 47 Thread_name = Thread-949 (fun)
# Iterazione: 47 Thread_name = Thread-950 (fun)
# Iterazione: 47 Thread_name = Thread-951 (fun)
# Iterazione: 47 Thread_name = Thread-952 (fun)
# Iterazione: 47 Thread_name = Thread-953 (fun)
# Iterazione: 47 Thread_name = Thread-954 (fun)
# Iterazione: 47 Thread_name = Thread-955 (fun)
# Iterazione: 47 Thread_name = Thread-956 (fun)
# Iterazione: 47 Thread_name = Thread-957 (fun)
# Iterazione: 47 Thread_name = Thread-958 (fun)
# Iterazione: 47 Thread_name = Thread-959 (fun)
# Iterazione: 47 Thread_name = Thread-960 (fun)
# Iterazione: 47 Thread_name = Thread-961 (fun)
# Iterazione: 47 Thread_name = Thread-962 (fun)
# Iterazione: 47 Thread_name = Thread-963 (fun)
# Iterazione: 48 Thread_name = Thread-964 (fun)
# Iterazione: 48 Thread_name = Thread-965 (fun)
# Iterazione: 48 Thread_name = Thread-966 (fun)
# Iterazione: 48 Thread_name = Thread-967 (fun)
# Iterazione: 48 Thread_name = Thread-968 (fun)
# Iterazione: 48 Thread_name = Thread-969 (fun)
# Iterazione: 48 Thread_name = Thread-970 (fun)
# Iterazione: 48 Thread_name = Thread-971 (fun)
# Iterazione: 48 Thread_name = Thread-972 (fun)
# Iterazione: 48 Thread_name = Thread-973 (fun)
# Iterazione: 48 Thread_name = Thread-974 (fun)
# Iterazione: 48 Thread_name = Thread-975 (fun)
# Iterazione: 48 Thread_name = Thread-976 (fun)
# Iterazione: 48 Thread_name = Thread-977 (fun)
# Iterazione: 48 Thread_name = Thread-978 (fun)
# Iterazione: 48 Thread_name = Thread-979 (fun)
# Iterazione: 48 Thread_name = Thread-980 (fun)
# Iterazione: 48 Thread_name = Thread-981 (fun)
# Iterazione: 48 Thread_name = Thread-982 (fun)
# Iterazione: 48 Thread_name = Thread-983 (fun)
# Iterazione: 49 Thread_name = Thread-984 (fun)
# Iterazione: 49 Thread_name = Thread-985 (fun)
# Iterazione: 49 Thread_name = Thread-986 (fun)
# Iterazione: 49 Thread_name = Thread-987 (fun)
# Iterazione: 49 Thread_name = Thread-988 (fun)
# Iterazione: 49 Thread_name = Thread-989 (fun)
# Iterazione: 49 Thread_name = Thread-990 (fun)
# Iterazione: 49 Thread_name = Thread-991 (fun)
# Iterazione: 49 Thread_name = Thread-992 (fun)
# Iterazione: 49 Thread_name = Thread-993 (fun)
# Iterazione: 49 Thread_name = Thread-994 (fun)
# Iterazione: 49 Thread_name = Thread-995 (fun)
# Iterazione: 49 Thread_name = Thread-996 (fun)
# Iterazione: 49 Thread_name = Thread-997 (fun)
# Iterazione: 49 Thread_name = Thread-998 (fun)
# Iterazione: 49 Thread_name = Thread-999 (fun)
# Iterazione: 49 Thread_name = Thread-1000 (fun)
# Iterazione: 49 Thread_name = Thread-1001 (fun)
# Iterazione: 49 Thread_name = Thread-1002 (fun)
# Iterazione: 49 Thread_name = Thread-1003 (fun)
# Iterazione: 50 Thread_name = Thread-1004 (fun)
# Iterazione: 50 Thread_name = Thread-1005 (fun)
# Iterazione: 50 Thread_name = Thread-1006 (fun)
# Iterazione: 50 Thread_name = Thread-1007 (fun)
# Iterazione: 50 Thread_name = Thread-1008 (fun)
# Iterazione: 50 Thread_name = Thread-1009 (fun)
# Iterazione: 50 Thread_name = Thread-1010 (fun)
# Iterazione: 50 Thread_name = Thread-1011 (fun)
# Iterazione: 50 Thread_name = Thread-1012 (fun)
# Iterazione: 50 Thread_name = Thread-1013 (fun)
# Iterazione: 50 Thread_name = Thread-1014 (fun)
# Iterazione: 50 Thread_name = Thread-1015 (fun)
# Iterazione: 50 Thread_name = Thread-1016 (fun)
# Iterazione: 50 Thread_name = Thread-1017 (fun)
# Iterazione: 50 Thread_name = Thread-1018 (fun)
# Iterazione: 50 Thread_name = Thread-1019 (fun)
# Iterazione: 50 Thread_name = Thread-1020 (fun)
# Iterazione: 50 Thread_name = Thread-1021 (fun)
# Iterazione: 50 Thread_name = Thread-1022 (fun)
# Iterazione: 50 Thread_name = Thread-1023 (fun)
# Iterazione: 51 Thread_name = Thread-1024 (fun)
# Iterazione: 51 Thread_name = Thread-1025 (fun)
# Iterazione: 51 Thread_name = Thread-1026 (fun)
# Iterazione: 51 Thread_name = Thread-1027 (fun)
# Iterazione: 51 Thread_name = Thread-1028 (fun)
# Iterazione: 51 Thread_name = Thread-1029 (fun)
# Iterazione: 51 Thread_name = Thread-1030 (fun)
# Iterazione: 51 Thread_name = Thread-1031 (fun)
# Iterazione: 51 Thread_name = Thread-1032 (fun)
# Iterazione: 51 Thread_name = Thread-1033 (fun)
# Iterazione: 51 Thread_name = Thread-1034 (fun)
# Iterazione: 51 Thread_name = Thread-1035 (fun)
# Iterazione: 51 Thread_name = Thread-1036 (fun)
# Iterazione: 51 Thread_name = Thread-1037 (fun)
# Iterazione: 51 Thread_name = Thread-1038 (fun)
# Iterazione: 51 Thread_name = Thread-1039 (fun)
# Iterazione: 51 Thread_name = Thread-1040 (fun)
# Iterazione: 51 Thread_name = Thread-1041 (fun)
# Iterazione: 51 Thread_name = Thread-1042 (fun)
# Iterazione: 51 Thread_name = Thread-1043 (fun)
# Iterazione: 52 Thread_name = Thread-1044 (fun)
# Iterazione: 52 Thread_name = Thread-1045 (fun)
# Iterazione: 52 Thread_name = Thread-1046 (fun)
# Iterazione: 52 Thread_name = Thread-1047 (fun)
# Iterazione: 52 Thread_name = Thread-1048 (fun)
# Iterazione: 52 Thread_name = Thread-1049 (fun)
# Iterazione: 52 Thread_name = Thread-1050 (fun)
# Iterazione: 52 Thread_name = Thread-1051 (fun)
# ...
# Iterazione: 603 Thread_name = Thread-12078 (fun)
# Iterazione: 603 Thread_name = Thread-12079 (fun)
# Iterazione: 603 Thread_name = Thread-12080 (fun)
# Iterazione: 603 Thread_name = Thread-12081 (fun)
# Iterazione: 603 Thread_name = Thread-12082 (fun)
# Iterazione: 603 Thread_name = Thread-12083 (fun)
# Iterazione: 604 Thread_name = Thread-12084 (fun)
# Iterazione: 604 Thread_name = Thread-12085 (fun)
# Iterazione: 604 Thread_name = Thread-12086 (fun)
# Iterazione: 604 Thread_name = Thread-12087 (fun)
# Iterazione: 604 Thread_name = Thread-12088 (fun)
# Iterazione: 604 Thread_name = Thread-12089 (fun)
# Iterazione: 604 Thread_name = Thread-12090 (fun)
# Iterazione: 604 Thread_name = Thread-12091 (fun)
# Iterazione: 604 Thread_name = Thread-12092 (fun)
# Iterazione: 604 Thread_name = Thread-12093 (fun)
# Iterazione: 604 Thread_name = Thread-12094 (fun)
# Iterazione: 604 Thread_name = Thread-12095 (fun)
# Iterazione: 604 Thread_name = Thread-12096 (fun)
# Iterazione: 604 Thread_name = Thread-12097 (fun)
# Iterazione: 604 Thread_name = Thread-12098 (fun)
# Iterazione: 604 Thread_name = Thread-12099 (fun)
# Iterazione: 604 Thread_name = Thread-12100 (fun)
# Iterazione: 604 Thread_name = Thread-12101 (fun)
# Iterazione: 604 Thread_name = Thread-12102 (fun)
# Iterazione: 604 Thread_name = Thread-12103 (fun)
# Iterazione: 605 Thread_name = Thread-12104 (fun)
# Iterazione: 605 Thread_name = Thread-12105 (fun)
# Iterazione: 605 Thread_name = Thread-12106 (fun)
# Iterazione: 605 Thread_name = Thread-12107 (fun)
# Iterazione: 605 Thread_name = Thread-12108 (fun)
# Iterazione: 605 Thread_name = Thread-12109 (fun)
# Iterazione: 605 Thread_name = Thread-12110 (fun)
# Iterazione: 605 Thread_name = Thread-12111 (fun)
# Iterazione: 605 Thread_name = Thread-12112 (fun)
# Iterazione: 605 Thread_name = Thread-12113 (fun)
# Iterazione: 605 Thread_name = Thread-12114 (fun)
# Iterazione: 605 Thread_name = Thread-12115 (fun)
# Iterazione: 605 Thread_name = Thread-12116 (fun)
# Iterazione: 605 Thread_name = Thread-12117 (fun)
# Iterazione: 605 Thread_name = Thread-12118 (fun)
# Iterazione: 605 Thread_name = Thread-12119 (fun)
# Iterazione: 605 Thread_name = Thread-12120 (fun)
# Iterazione: 605 Thread_name = Thread-12121 (fun)
# Iterazione: 605 Thread_name = Thread-12122 (fun)
# Iterazione: 605 Thread_name = Thread-12123 (fun)
# Iterazione: 606 Thread_name = Thread-12124 (fun)
# Iterazione: 606 Thread_name = Thread-12125 (fun)
# Iterazione: 606 Thread_name = Thread-12126 (fun)
# Iterazione: 606 Thread_name = Thread-12127 (fun)
# Iterazione: 606 Thread_name = Thread-12128 (fun)
# Iterazione: 606 Thread_name = Thread-12129 (fun)
# Iterazione: 606 Thread_name = Thread-12130 (fun)
# Iterazione: 606 Thread_name = Thread-12131 (fun)
# Iterazione: 606 Thread_name = Thread-12132 (fun)
# Iterazione: 606 Thread_name = Thread-12133 (fun)
# Iterazione: 606 Thread_name = Thread-12134 (fun)
# Iterazione: 606 Thread_name = Thread-12135 (fun)
# Iterazione: 606 Thread_name = Thread-12136 (fun)
# Iterazione: 606 Thread_name = Thread-12137 (fun)
# Iterazione: 606 Thread_name = Thread-12138 (fun)
# Iterazione: 606 Thread_name = Thread-12139 (fun)
# Iterazione: 606 Thread_name = Thread-12140 (fun)
# Iterazione: 606 Thread_name = Thread-12141 (fun)
# Iterazione: 606 Thread_name = Thread-12142 (fun)
# Iterazione: 606 Thread_name = Thread-12143 (fun)
# Iterazione: 607 Thread_name = Thread-12144 (fun)
# Iterazione: 607 Thread_name = Thread-12145 (fun)
# Iterazione: 607 Thread_name = Thread-12146 (fun)
# Iterazione: 607 Thread_name = Thread-12147 (fun)
# Iterazione: 607 Thread_name = Thread-12148 (fun)
# Iterazione: 607 Thread_name = Thread-12149 (fun)
# Iterazione: 607 Thread_name = Thread-12150 (fun)
# Iterazione: 607 Thread_name = Thread-12151 (fun)
# Iterazione: 607 Thread_name = Thread-12152 (fun)
# Iterazione: 607 Thread_name = Thread-12153 (fun)
# Iterazione: 607 Thread_name = Thread-12154 (fun)
# Iterazione: 607 Thread_name = Thread-12155 (fun)
# Iterazione: 607 Thread_name = Thread-12156 (fun)
# Iterazione: 607 Thread_name = Thread-12157 (fun)
# Iterazione: 607 Thread_name = Thread-12158 (fun)
# Iterazione: 607 Thread_name = Thread-12159 (fun)
# Iterazione: 607 Thread_name = Thread-12160 (fun)
# Iterazione: 607 Thread_name = Thread-12161 (fun)
# Iterazione: 607 Thread_name = Thread-12162 (fun)
# Iterazione: 607 Thread_name = Thread-12163 (fun)
# Iterazione: 608 Thread_name = Thread-12164 (fun)
# Iterazione: 608 Thread_name = Thread-12165 (fun)
# Iterazione: 608 Thread_name = Thread-12166 (fun)
# Iterazione: 608 Thread_name = Thread-12167 (fun)
# Iterazione: 608 Thread_name = Thread-12168 (fun)
# Iterazione: 608 Thread_name = Thread-12169 (fun)
# Iterazione: 608 Thread_name = Thread-12170 (fun)
# Iterazione: 608 Thread_name = Thread-12171 (fun)
# Iterazione: 608 Thread_name = Thread-12172 (fun)
# Iterazione: 608 Thread_name = Thread-12173 (fun)
# Iterazione: 608 Thread_name = Thread-12174 (fun)
# Iterazione: 608 Thread_name = Thread-12175 (fun)
# Iterazione: 608 Thread_name = Thread-12176 (fun)
# Iterazione: 608 Thread_name = Thread-12177 (fun)
# Iterazione: 608 Thread_name = Thread-12178 (fun)
# Iterazione: 608 Thread_name = Thread-12179 (fun)
# Iterazione: 608 Thread_name = Thread-12180 (fun)
# Iterazione: 608 Thread_name = Thread-12181 (fun)
# Iterazione: 608 Thread_name = Thread-12182 (fun)
# Iterazione: 608 Thread_name = Thread-12183 (fun)
# Iterazione: 609 Thread_name = Thread-12184 (fun)
# Iterazione: 609 Thread_name = Thread-12185 (fun)
# Iterazione: 609 Thread_name = Thread-12186 (fun)
# Iterazione: 609 Thread_name = Thread-12187 (fun)
# Iterazione: 609 Thread_name = Thread-12188 (fun)
# Iterazione: 609 Thread_name = Thread-12189 (fun)
# Iterazione: 609 Thread_name = Thread-12190 (fun)
# Iterazione: 609 Thread_name = Thread-12191 (fun)
# Iterazione: 609 Thread_name = Thread-12192 (fun)
# Iterazione: 609 Thread_name = Thread-12193 (fun)
# Iterazione: 609 Thread_name = Thread-12194 (fun)
# Iterazione: 609 Thread_name = Thread-12195 (fun)
# Iterazione: 609 Thread_name = Thread-12196 (fun)
# Iterazione: 609 Thread_name = Thread-12197 (fun)
# Iterazione: 609 Thread_name = Thread-12198 (fun)
# Iterazione: 609 Thread_name = Thread-12199 (fun)
# Iterazione: 609 Thread_name = Thread-12200 (fun)
# Iterazione: 609 Thread_name = Thread-12201 (fun)
# Iterazione: 609 Thread_name = Thread-12202 (fun)
# Iterazione: 609 Thread_name = Thread-12203 (fun)
# Iterazione: 610 Thread_name = Thread-12204 (fun)
# Iterazione: 610 Thread_name = Thread-12205 (fun)
# Iterazione: 610 Thread_name = Thread-12206 (fun)
# Iterazione: 610 Thread_name = Thread-12207 (fun)
# Iterazione: 610 Thread_name = Thread-12208 (fun)
# Iterazione: 610 Thread_name = Thread-12209 (fun)
# Iterazione: 610 Thread_name = Thread-12210 (fun)
# Iterazione: 610 Thread_name = Thread-12211 (fun)
# Iterazione: 610 Thread_name = Thread-12212 (fun)
# Iterazione: 610 Thread_name = Thread-12213 (fun)
# Iterazione: 610 Thread_name = Thread-12214 (fun)
# Iterazione: 610 Thread_name = Thread-12215 (fun)
# Iterazione: 610 Thread_name = Thread-12216 (fun)
# Iterazione: 610 Thread_name = Thread-12217 (fun)
# Iterazione: 610 Thread_name = Thread-12218 (fun)
# Iterazione: 610 Thread_name = Thread-12219 (fun)
# Iterazione: 610 Thread_name = Thread-12220 (fun)
# Iterazione: 610 Thread_name = Thread-12221 (fun)
# Iterazione: 610 Thread_name = Thread-12222 (fun)
# Iterazione: 610 Thread_name = Thread-12223 (fun)
# Iterazione: 611 Thread_name = Thread-12224 (fun)
# Iterazione: 611 Thread_name = Thread-12225 (fun)
# Iterazione: 611 Thread_name = Thread-12226 (fun)
# Iterazione: 611 Thread_name = Thread-12227 (fun)
# Iterazione: 611 Thread_name = Thread-12228 (fun)
# Iterazione: 611 Thread_name = Thread-12229 (fun)
# Iterazione: 611 Thread_name = Thread-12230 (fun)
# Iterazione: 611 Thread_name = Thread-12231 (fun)
# Iterazione: 611 Thread_name = Thread-12232 (fun)
# Iterazione: 611 Thread_name = Thread-12233 (fun)
# Iterazione: 611 Thread_name = Thread-12234 (fun)
# Iterazione: 611 Thread_name = Thread-12235 (fun)
# Iterazione: 611 Thread_name = Thread-12236 (fun)
# Iterazione: 611 Thread_name = Thread-12237 (fun)
# Iterazione: 611 Thread_name = Thread-12238 (fun)
# Iterazione: 611 Thread_name = Thread-12239 (fun)
# Iterazione: 611 Thread_name = Thread-12240 (fun)
# Iterazione: 611 Thread_name = Thread-12241 (fun)
# Iterazione: 611 Thread_name = Thread-12242 (fun)
# Iterazione: 611 Thread_name = Thread-12243 (fun)
# Iterazione: 612 Thread_name = Thread-12244 (fun)
# Iterazione: 612 Thread_name = Thread-12245 (fun)
# Iterazione: 612 Thread_name = Thread-12246 (fun)
# Iterazione: 612 Thread_name = Thread-12247 (fun)
# Iterazione: 612 Thread_name = Thread-12248 (fun)
# Iterazione: 612 Thread_name = Thread-12249 (fun)
# Iterazione: 612 Thread_name = Thread-12250 (fun)
# Iterazione: 612 Thread_name = Thread-12251 (fun)
# Iterazione: 612 Thread_name = Thread-12252 (fun)
# Iterazione: 612 Thread_name = Thread-12253 (fun)
# Iterazione: 612 Thread_name = Thread-12254 (fun)
# Iterazione: 612 Thread_name = Thread-12255 (fun)
# Iterazione: 612 Thread_name = Thread-12256 (fun)
# Iterazione: 612 Thread_name = Thread-12257 (fun)
# Iterazione: 612 Thread_name = Thread-12258 (fun)
# Iterazione: 612 Thread_name = Thread-12259 (fun)
# Iterazione: 612 Thread_name = Thread-12260 (fun)
# Iterazione: 612 Thread_name = Thread-12261 (fun)
# Iterazione: 612 Thread_name = Thread-12262 (fun)
# Iterazione: 612 Thread_name = Thread-12263 (fun)
# Iterazione: 613 Thread_name = Thread-12264 (fun)
# Iterazione: 613 Thread_name = Thread-12265 (fun)
# Iterazione: 613 Thread_name = Thread-12266 (fun)
# Iterazione: 613 Thread_name = Thread-12267 (fun)
# Iterazione: 613 Thread_name = Thread-12268 (fun)
# Iterazione: 613 Thread_name = Thread-12269 (fun)
# Iterazione: 613 Thread_name = Thread-12270 (fun)
# Iterazione: 613 Thread_name = Thread-12271 (fun)
# Iterazione: 613 Thread_name = Thread-12272 (fun)
# Iterazione: 613 Thread_name = Thread-12273 (fun)
# Iterazione: 613 Thread_name = Thread-12274 (fun)
# Iterazione: 613 Thread_name = Thread-12275 (fun)
# Iterazione: 613 Thread_name = Thread-12276 (fun)
# Iterazione: 613 Thread_name = Thread-12277 (fun)
# Iterazione: 613 Thread_name = Thread-12278 (fun)
# Iterazione: 613 Thread_name = Thread-12279 (fun)
# Iterazione: 613 Thread_name = Thread-12280 (fun)
# Iterazione: 613 Thread_name = Thread-12281 (fun)
# Iterazione: 613 Thread_name = Thread-12282 (fun)
# Iterazione: 613 Thread_name = Thread-12283 (fun)
# Iterazione: 614 Thread_name = Thread-12284 (fun)
# Iterazione: 614 Thread_name = Thread-12285 (fun)
# Iterazione: 614 Thread_name = Thread-12286 (fun)
# Iterazione: 614 Thread_name = Thread-12287 (fun)
# Iterazione: 614 Thread_name = Thread-12288 (fun)
# Iterazione: 614 Thread_name = Thread-12289 (fun)
# Iterazione: 614 Thread_name = Thread-12290 (fun)
# Iterazione: 614 Thread_name = Thread-12291 (fun)
# Iterazione: 614 Thread_name = Thread-12292 (fun)
# Iterazione: 614 Thread_name = Thread-12293 (fun)
# Iterazione: 614 Thread_name = Thread-12294 (fun)
# Iterazione: 614 Thread_name = Thread-12295 (fun)
# Iterazione: 614 Thread_name = Thread-12296 (fun)
# Iterazione: 614 Thread_name = Thread-12297 (fun)
# Iterazione: 614 Thread_name = Thread-12298 (fun)
# Iterazione: 614 Thread_name = Thread-12299 (fun)
# Iterazione: 614 Thread_name = Thread-12300 (fun)
# Iterazione: 614 Thread_name = Thread-12301 (fun)
# Iterazione: 614 Thread_name = Thread-12302 (fun)
# Iterazione: 614 Thread_name = Thread-12303 (fun)
# Iterazione: 615 Thread_name = Thread-12304 (fun)
# Iterazione: 615 Thread_name = Thread-12305 (fun)
# Iterazione: 615 Thread_name = Thread-12306 (fun)
# Iterazione: 615 Thread_name = Thread-12307 (fun)
# Iterazione: 615 Thread_name = Thread-12308 (fun)
# Iterazione: 615 Thread_name = Thread-12309 (fun)
# Iterazione: 615 Thread_name = Thread-12310 (fun)
# Iterazione: 615 Thread_name = Thread-12311 (fun)
# Iterazione: 615 Thread_name = Thread-12312 (fun)
# Iterazione: 615 Thread_name = Thread-12313 (fun)
# Iterazione: 615 Thread_name = Thread-12314 (fun)
# Iterazione: 615 Thread_name = Thread-12315 (fun)
# Iterazione: 615 Thread_name = Thread-12316 (fun)
# Iterazione: 615 Thread_name = Thread-12317 (fun)
# Iterazione: 615 Thread_name = Thread-12318 (fun)
# Iterazione: 615 Thread_name = Thread-12319 (fun)
# Iterazione: 615 Thread_name = Thread-12320 (fun)
# Iterazione: 615 Thread_name = Thread-12321 (fun)
# Iterazione: 615 Thread_name = Thread-12322 (fun)
# Iterazione: 615 Thread_name = Thread-12323 (fun)
# Iterazione: 616 Thread_name = Thread-12324 (fun)
# Iterazione: 616 Thread_name = Thread-12325 (fun)
# Iterazione: 616 Thread_name = Thread-12326 (fun)
# Iterazione: 616 Thread_name = Thread-12327 (fun)
# Iterazione: 616 Thread_name = Thread-12328 (fun)
# Iterazione: 616 Thread_name = Thread-12329 (fun)
# Iterazione: 616 Thread_name = Thread-12330 (fun)
# Iterazione: 616 Thread_name = Thread-12331 (fun)
# Iterazione: 616 Thread_name = Thread-12332 (fun)
# Iterazione: 616 Thread_name = Thread-12333 (fun)
# Iterazione: 616 Thread_name = Thread-12334 (fun)
# Iterazione: 616 Thread_name = Thread-12335 (fun)
# Iterazione: 616 Thread_name = Thread-12336 (fun)
# Iterazione: 616 Thread_name = Thread-12337 (fun)
# Iterazione: 616 Thread_name = Thread-12338 (fun)
# Iterazione: 616 Thread_name = Thread-12339 (fun)
# Iterazione: 616 Thread_name = Thread-12340 (fun)
# Iterazione: 616 Thread_name = Thread-12341 (fun)
# Iterazione: 616 Thread_name = Thread-12342 (fun)
# Iterazione: 616 Thread_name = Thread-12343 (fun)
# Iterazione: 617 Thread_name = Thread-12344 (fun)
# Iterazione: 617 Thread_name = Thread-12345 (fun)
# Iterazione: 617 Thread_name = Thread-12346 (fun)
# Iterazione: 617 Thread_name = Thread-12347 (fun)
# Iterazione: 617 Thread_name = Thread-12348 (fun)
# Iterazione: 617 Thread_name = Thread-12349 (fun)
# Iterazione: 617 Thread_name = Thread-12350 (fun)
# Iterazione: 617 Thread_name = Thread-12351 (fun)
# Iterazione: 617 Thread_name = Thread-12352 (fun)
# Iterazione: 617 Thread_name = Thread-12353 (fun)
# Iterazione: 617 Thread_name = Thread-12354 (fun)
# Iterazione: 617 Thread_name = Thread-12355 (fun)
# Iterazione: 617 Thread_name = Thread-12356 (fun)
# Iterazione: 617 Thread_name = Thread-12357 (fun)
# Iterazione: 617 Thread_name = Thread-12358 (fun)
# Iterazione: 617 Thread_name = Thread-12359 (fun)
# Iterazione: 617 Thread_name = Thread-12360 (fun)
# Iterazione: 617 Thread_name = Thread-12361 (fun)
# Iterazione: 617 Thread_name = Thread-12362 (fun)
# Iterazione: 617 Thread_name = Thread-12363 (fun)
# Iterazione: 618 Thread_name = Thread-12364 (fun)
# Iterazione: 618 Thread_name = Thread-12365 (fun)
# Iterazione: 618 Thread_name = Thread-12366 (fun)
# Iterazione: 618 Thread_name = Thread-12367 (fun)
# Iterazione: 618 Thread_name = Thread-12368 (fun)
# Iterazione: 618 Thread_name = Thread-12369 (fun)
# Iterazione: 618 Thread_name = Thread-12370 (fun)
# Iterazione: 618 Thread_name = Thread-12371 (fun)
# Iterazione: 618 Thread_name = Thread-12372 (fun)
# Iterazione: 618 Thread_name = Thread-12373 (fun)
# Iterazione: 618 Thread_name = Thread-12374 (fun)
# Iterazione: 618 Thread_name = Thread-12375 (fun)
# Iterazione: 618 Thread_name = Thread-12376 (fun)
# Iterazione: 618 Thread_name = Thread-12377 (fun)
# Iterazione: 618 Thread_name = Thread-12378 (fun)
# Iterazione: 618 Thread_name = Thread-12379 (fun)
# Iterazione: 618 Thread_name = Thread-12380 (fun)
# Iterazione: 618 Thread_name = Thread-12381 (fun)
# Iterazione: 618 Thread_name = Thread-12382 (fun)
# Iterazione: 618 Thread_name = Thread-12383 (fun)
# Iterazione: 619 Thread_name = Thread-12384 (fun)
# Iterazione: 619 Thread_name = Thread-12385 (fun)
# Iterazione: 619 Thread_name = Thread-12386 (fun)
# Iterazione: 619 Thread_name = Thread-12387 (fun)
# Iterazione: 619 Thread_name = Thread-12388 (fun)
# Iterazione: 619 Thread_name = Thread-12389 (fun)
# Iterazione: 619 Thread_name = Thread-12390 (fun)
# Iterazione: 619 Thread_name = Thread-12391 (fun)
# Iterazione: 619 Thread_name = Thread-12392 (fun)
# Iterazione: 619 Thread_name = Thread-12393 (fun)
# Iterazione: 619 Thread_name = Thread-12394 (fun)
# Iterazione: 619 Thread_name = Thread-12395 (fun)
# Iterazione: 619 Thread_name = Thread-12396 (fun)
# Iterazione: 619 Thread_name = Thread-12397 (fun)
# Iterazione: 619 Thread_name = Thread-12398 (fun)
# Iterazione: 619 Thread_name = Thread-12399 (fun)
# Iterazione: 619 Thread_name = Thread-12400 (fun)
# Iterazione: 619 Thread_name = Thread-12401 (fun)
# Iterazione: 619 Thread_name = Thread-12402 (fun)
# Iterazione: 619 Thread_name = Thread-12403 (fun)

# %%
df = pd.DataFrame(outputs)
df = df.transpose()
df.columns=headers

# %%
if not os.path.isfile('server.csv'):
   df.to_csv('server.csv',index=False)
else: 
   df.to_csv('server.csv', index = False,mode='a', header=False)
